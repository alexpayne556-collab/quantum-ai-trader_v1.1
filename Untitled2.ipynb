# %%
# Install required packages
# !pip install -q yfinance pandas numpy requests beautifulsoup4 lxml
# !pip install -q torch transformers sentence-transformers
# !pip install -q matplotlib seaborn plotly

print("✅ Packages installed")

# %%
# Import all libraries
import pandas as pd
import numpy as np
import yfinance as yf
import requests
from bs4 import BeautifulSoup
import time
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# GPU check
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("⚠️ Running on CPU")

print("\n✅ All imports successful")

# %%
# Browser headers (crucial for scraping)
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# Auto-detect environment and set paths
import os
import sys

# Check if running in Codespace (Linux) or local (Windows/Mac)
if os.path.exists('/workspaces/quantum-ai-trader_v1.1'):
    # Codespace environment
    WORKSPACE_ROOT = '/workspaces/quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'):
    # Shadow PC (original path)
    WORKSPACE_ROOT = r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\Shadow\quantum-ai-trader_v1.1'):
    # Shadow PC (alternate path)
    WORKSPACE_ROOT = r'C:\Users\Shadow\quantum-ai-trader_v1.1'
else:
    # Try relative path from notebook location
    notebook_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
    WORKSPACE_ROOT = os.path.abspath(os.path.join(notebook_dir, '..'))

DATA_DIR = os.path.join(WORKSPACE_ROOT, 'data')
UNIVERSE_FILE = os.path.join(DATA_DIR, 'ticker_universe_300.csv')
OUTPUT_FILE = os.path.join(DATA_DIR, 'research_results_top50.csv')

# Verify paths exist
print(f"✅ Workspace: {WORKSPACE_ROOT}")
print(f"✅ Data directory: {DATA_DIR}")
print(f"✅ Universe file: {UNIVERSE_FILE}")
print(f"✅ File exists: {os.path.exists(UNIVERSE_FILE)}")

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)
    print(f"📁 Created data directory")

# %%
# Browser headers (crucial for scraping)
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# Auto-detect environment and set paths
import os
import sys

# Check if running in Codespace (Linux) or local (Windows/Mac)
if os.path.exists('/workspaces/quantum-ai-trader_v1.1'):
    # Codespace environment
    WORKSPACE_ROOT = '/workspaces/quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'):
    # Shadow PC (original path)
    WORKSPACE_ROOT = r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\Shadow\quantum-ai-trader_v1.1'):
    # Shadow PC (alternate path)
    WORKSPACE_ROOT = r'C:\Users\Shadow\quantum-ai-trader_v1.1'
else:
    # Try relative path from notebook location
    notebook_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
    WORKSPACE_ROOT = os.path.abspath(os.path.join(notebook_dir, '..'))

DATA_DIR = os.path.join(WORKSPACE_ROOT, 'data')
UNIVERSE_FILE = os.path.join(DATA_DIR, 'ticker_universe_300.csv')
OUTPUT_FILE = os.path.join(DATA_DIR, 'research_results_top50.csv')

# Verify paths exist
print(f"✅ Workspace: {WORKSPACE_ROOT}")
print(f"✅ Data directory: {DATA_DIR}")
print(f"✅ Universe file: {UNIVERSE_FILE}")
print(f"✅ File exists: {os.path.exists(UNIVERSE_FILE)}")

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)
    print(f"📁 Created data directory")

# %%
# IF FILE DOESN'T EXIST: Download from GitHub or create sample
if not os.path.exists(UNIVERSE_FILE):
    print("⚠️ Universe file not found. Creating sample...")
    
    # Option 1: Try to download from GitHub
    import requests
    try:
        url = "https://raw.githubusercontent.com/alexpayne556-collab/quantum-ai-trader_v1.1/main/data/ticker_universe_300.csv"
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            with open(UNIVERSE_FILE, 'wb') as f:
                f.write(response.content)
            print(f"✅ Downloaded from GitHub to {UNIVERSE_FILE}")
        else:
            raise Exception("GitHub download failed")
    except:
        # Option 2: Create minimal sample for testing
        print("⚠️ Creating minimal sample (replace with full list later)")
        sample_tickers = [
            ('AAPL', 'Technology', 'Consumer Electronics', 'Large Cap', 'Benchmark'),
            ('NVDA', 'Technology', 'Semiconductors', 'Large Cap', 'AI Leader'),
            ('IONQ', 'Technology', 'Quantum Computing', 'Small Cap', 'Current Holding'),
            ('ASTS', 'Communications', 'Space', 'Small Cap', 'Current Holding'),
            ('HOOD', 'Fintech', 'Brokerage', 'Mid Cap', 'Current Holding'),
            ('MARA', 'Crypto', 'Bitcoin Mining', 'Small Cap', 'Mining Leader'),
            ('PLTR', 'Technology', 'Software', 'Mid Cap', 'AI/Data'),
            ('TSLA', 'Automotive', 'Electric Vehicles', 'Large Cap', 'Innovation'),
            ('AMD', 'Technology', 'Semiconductors', 'Large Cap', 'AI/GPU'),
            ('SOFI', 'Fintech', 'Banking', 'Small Cap', 'Digital Bank'),
        ]
        import pandas as pd
        df = pd.DataFrame(sample_tickers, columns=['ticker', 'sector', 'industry', 'market_cap_category', 'notes'])
        df.to_csv(UNIVERSE_FILE, index=False)
        print(f"✅ Created sample file: {UNIVERSE_FILE}")
        print("⚠️ IMPORTANT: Replace this with your full 353-ticker list!")
else:
    print("✅ Universe file found")

# %%
# Load 300-ticker universe
universe_df = pd.read_csv(UNIVERSE_FILE)

print(f"📊 Loaded {len(universe_df)} tickers\n")
print("Sector breakdown:")
print(universe_df['sector'].value_counts())
print("\nFirst 10 tickers:")
print(universe_df.head(10))

# %%
# Get ticker list
TICKERS = universe_df['ticker'].tolist()

print(f"✅ {len(TICKERS)} tickers ready for analysis")
print(f"\nSample: {TICKERS[:20]}")

# %%
def collect_ohlcv_batch(tickers, period='2y', batch_size=50):
    """
    Collect OHLCV data using yfinance (unlimited, free)
    Batch processing to avoid memory issues
    """
    all_data = {}
    failed = []
    
    for i in range(0, len(tickers), batch_size):
        batch = tickers[i:i+batch_size]
        print(f"Fetching batch {i//batch_size + 1} ({len(batch)} tickers)...")
        
        try:
            # Download batch (yfinance handles multiple tickers efficiently)
            data = yf.download(batch, period=period, group_by='ticker', 
                             progress=False, threads=True)
            
            # Store each ticker's data
            for ticker in batch:
                try:
                    if len(batch) == 1:
                        ticker_data = data
                    else:
                        ticker_data = data[ticker]
                    
                    if not ticker_data.empty and len(ticker_data) > 20:
                        all_data[ticker] = ticker_data
                    else:
                        failed.append(ticker)
                except:
                    failed.append(ticker)
            
            time.sleep(0.5)  # Polite delay
            
        except Exception as e:
            print(f"  Error in batch: {e}")
            failed.extend(batch)
    
    print(f"\n✅ Collected: {len(all_data)}/{len(tickers)} tickers")
    if failed:
        print(f"❌ Failed: {len(failed)} tickers - {failed[:10]}")
    
    return all_data, failed

# Test with first 20 tickers
print("🔄 Testing OHLCV collection with 20 tickers...")
test_tickers = TICKERS[:20]
ohlcv_data, failed_tickers = collect_ohlcv_batch(test_tickers, period='1y')

# Show sample
if ohlcv_data:
    sample_ticker = list(ohlcv_data.keys())[0]
    print(f"\nSample data for {sample_ticker}:")
    print(ohlcv_data[sample_ticker].tail())

# %%
def scrape_yahoo_fundamentals(ticker):
    """
    Scrape Yahoo Finance key statistics (P/E, short interest, etc.)
    Uses pandas.read_html to extract tables directly
    """
    url = f"https://finance.yahoo.com/quote/{ticker}/key-statistics"
    
    try:
        # Download all tables from the page
        tables = pd.read_html(requests.get(url, headers=HEADERS, timeout=10).text)
        
        # Combine all tables into one lookup dictionary
        stats_dict = {}
        for table in tables:
            if len(table.columns) >= 2:
                # Convert table to dict (column 0 = key, column 1 = value)
                for idx, row in table.iterrows():
                    try:
                        stats_dict[row.iloc[0]] = row.iloc[1]
                    except:
                        pass
        
        # Extract key metrics
        fundamentals = {
            'ticker': ticker,
            'market_cap': stats_dict.get('Market Cap (intraday)', 'N/A'),
            'trailing_pe': stats_dict.get('Trailing P/E', 'N/A'),
            'forward_pe': stats_dict.get('Forward P/E', 'N/A'),
            'peg_ratio': stats_dict.get('PEG Ratio (5 yr expected)', 'N/A'),
            'price_book': stats_dict.get('Price/Book (mrq)', 'N/A'),
            'price_sales': stats_dict.get('Price/Sales (ttm)', 'N/A'),
            'short_pct': stats_dict.get('Short % of Float', 'N/A'),
            'short_ratio': stats_dict.get('Short Ratio', 'N/A'),
            'insider_pct': stats_dict.get('% Held by Insiders', 'N/A'),
            'institution_pct': stats_dict.get('% Held by Institutions', 'N/A'),
            'beta': stats_dict.get('Beta (5Y Monthly)', 'N/A'),
            'forward_div': stats_dict.get('Forward Annual Dividend Yield', 'N/A'),
        }
        
        return fundamentals
        
    except Exception as e:
        return {'ticker': ticker, 'error': str(e)}

# Test on 5 tickers
print("🔄 Testing fundamentals scraper...")
test_funds = []
for ticker in TICKERS[:5]:
    print(f"  Scraping {ticker}...")
    fund = scrape_yahoo_fundamentals(ticker)
    test_funds.append(fund)
    time.sleep(1)  # Polite delay

fund_df = pd.DataFrame(test_funds)
print("\n✅ Sample fundamentals:")
print(fund_df[['ticker', 'market_cap', 'trailing_pe', 'short_pct', 'insider_pct']])

# %%
# Browser headers (crucial for scraping)
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# Auto-detect environment and set paths
import os
import sys

# Check if running in Codespace (Linux) or local (Windows/Mac)
if os.path.exists('/workspaces/quantum-ai-trader_v1.1'):
    # Codespace environment
    WORKSPACE_ROOT = '/workspaces/quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'):
    # Shadow PC (original path)
    WORKSPACE_ROOT = r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\Shadow\quantum-ai-trader_v1.1'):
    # Shadow PC (alternate path)
    WORKSPACE_ROOT = r'C:\Users\Shadow\quantum-ai-trader_v1.1'
else:
    # Try relative path from notebook location
    notebook_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
    WORKSPACE_ROOT = os.path.abspath(os.path.join(notebook_dir, '..'))

DATA_DIR = os.path.join(WORKSPACE_ROOT, 'data')
UNIVERSE_FILE = os.path.join(DATA_DIR, 'ticker_universe_300.csv')
OUTPUT_FILE = os.path.join(DATA_DIR, 'research_results_top50.csv')

# Verify paths exist
print(f"✅ Workspace: {WORKSPACE_ROOT}")
print(f"✅ Data directory: {DATA_DIR}")
print(f"✅ Universe file: {UNIVERSE_FILE}")
print(f"✅ File exists: {os.path.exists(UNIVERSE_FILE)}")

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)
    print(f"📁 Created data directory")

# %%
# Browser headers (crucial for scraping)
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# Auto-detect environment and set paths
import os
import sys

# Check if running in Codespace (Linux) or local (Windows/Mac)
if os.path.exists('/workspaces/quantum-ai-trader_v1.1'):
    # Codespace environment
    WORKSPACE_ROOT = '/workspaces/quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'):
    # Shadow PC (original path)
    WORKSPACE_ROOT = r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\Shadow\quantum-ai-trader_v1.1'):
    # Shadow PC (alternate path)
    WORKSPACE_ROOT = r'C:\Users\Shadow\quantum-ai-trader_v1.1'
else:
    # Try relative path from notebook location
    notebook_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
    WORKSPACE_ROOT = os.path.abspath(os.path.join(notebook_dir, '..'))

DATA_DIR = os.path.join(WORKSPACE_ROOT, 'data')
UNIVERSE_FILE = os.path.join(DATA_DIR, 'ticker_universe_300.csv')
OUTPUT_FILE = os.path.join(DATA_DIR, 'research_results_top50.csv')

# Verify paths exist
print(f"✅ Workspace: {WORKSPACE_ROOT}")
print(f"✅ Data directory: {DATA_DIR}")
print(f"✅ Universe file: {UNIVERSE_FILE}")
print(f"✅ File exists: {os.path.exists(UNIVERSE_FILE)}")

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)
    print(f"📁 Created data directory")

# %%
# Load 300-ticker universe
universe_df = pd.read_csv(UNIVERSE_FILE)

print(f"📊 Loaded {len(universe_df)} tickers\n")
print("Sector breakdown:")
print(universe_df['sector'].value_counts())
print("\nFirst 10 tickers:")
print(universe_df.head(10))

# %%
def scrape_yahoo_fundamentals(ticker):
    """
    Scrape Yahoo Finance key statistics (P/E, short interest, etc.)
    Uses pandas.read_html to extract tables directly
    """
    url = f"https://finance.yahoo.com/quote/{ticker}/key-statistics"
    
    try:
        # Download page
        response = requests.get(url, headers=HEADERS, timeout=10)
        
        if response.status_code != 200:
            return {'ticker': ticker, 'error': f'HTTP {response.status_code}'}
        
        # Try to extract tables
        try:
            tables = pd.read_html(response.text)
        except ValueError as e:
            # No tables found - Yahoo might have changed format
            return {'ticker': ticker, 'error': 'No tables found on page'}
        
        # Combine all tables into one lookup dictionary
        stats_dict = {}
        for table in tables:
            if len(table.columns) >= 2:
                # Convert table to dict (column 0 = key, column 1 = value)
                for idx, row in table.iterrows():
                    try:
                        stats_dict[row.iloc[0]] = row.iloc[1]
                    except:
                        pass
        
        if not stats_dict:
            return {'ticker': ticker, 'error': 'No data extracted from tables'}
        
        # Extract key metrics
        fundamentals = {
            'ticker': ticker,
            'market_cap': stats_dict.get('Market Cap (intraday)', 'N/A'),
            'trailing_pe': stats_dict.get('Trailing P/E', 'N/A'),
            'forward_pe': stats_dict.get('Forward P/E', 'N/A'),
            'peg_ratio': stats_dict.get('PEG Ratio (5 yr expected)', 'N/A'),
            'price_book': stats_dict.get('Price/Book (mrq)', 'N/A'),
            'price_sales': stats_dict.get('Price/Sales (ttm)', 'N/A'),
            'short_pct': stats_dict.get('Short % of Float', 'N/A'),
            'short_ratio': stats_dict.get('Short Ratio', 'N/A'),
            'insider_pct': stats_dict.get('% Held by Insiders', 'N/A'),
            'institution_pct': stats_dict.get('% Held by Institutions', 'N/A'),
            'beta': stats_dict.get('Beta (5Y Monthly)', 'N/A'),
            'forward_div': stats_dict.get('Forward Annual Dividend Yield', 'N/A'),
        }
        
        return fundamentals
        
    except Exception as e:
        return {'ticker': ticker, 'error': str(e)}

# Test on YOUR stocks (not blue chips)
print("🔄 Testing fundamentals scraper on YOUR holdings...")
test_tickers_fund = ['IONQ', 'ASTS', 'HOOD', 'MARA', 'PLTR']
test_funds = []

for ticker in test_tickers_fund:
    print(f"  Scraping {ticker}...")
    fund = scrape_yahoo_fundamentals(ticker)
    test_funds.append(fund)
    
    # Show what we got (debug)
    if 'error' in fund:
        print(f"    ❌ Error: {fund['error'][:50]}")
    else:
        print(f"    ✅ Got data")
    
    time.sleep(1)  # Polite delay

fund_df = pd.DataFrame(test_funds)
print("\n📊 Raw results:")
print(fund_df)

# Only show these columns if they exist
if 'market_cap' in fund_df.columns:
    print("\n✅ Sample fundamentals:")
    print(fund_df[['ticker', 'market_cap', 'trailing_pe', 'short_pct', 'insider_pct']])
else:
    print("\n⚠️ Scraping failed - check errors above")

# %%
import yfinance as yf
stock = yf.Ticker('IONQ')
print(stock.info)  # See if this has all the data!

# %%
import logging
from typing import Dict, Any, Optional
from datetime import datetime

# ==================== HARDCODED API KEYS ====================
FMP_API_KEY = "15zYYtksuJnQsTBODSNs3MrfEedOSd3i"
ALPHA_VANTAGE_API_KEY = "0ROKR956QR1XHDLZ"

# ==================== CONFIGURE LOGGING ====================
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[logging.FileHandler('data/fundamentals_collector.log'),
                              logging.StreamHandler()])
logger = logging.getLogger(__name__)

# ==================== PRIMARY SOURCE: yfinance ====================
def fetch_yfinance(ticker: str) -> Dict[str, Any]:
    """Fetch data from yfinance. Returns dict with source attribution."""
    data = {}
    source = "yfinance"
    try:
        stock = yf.Ticker(ticker)
        info = stock.info

        # Map yfinance fields to standardized names
        field_mapping = {
            'marketCap': 'market_cap',
            'trailingPE': 'trailing_pe',
            'forwardPE': 'forward_pe',
            'shortPercentOfFloat': 'short_pct',
            'heldPercentInsiders': 'insider_pct',
            'heldPercentInstitutions': 'institution_pct',
            'beta': 'beta',
            'priceToBook': 'price_to_book',
            'priceToSalesTrailing12Months': 'price_to_sales',
            'pegRatio': 'peg_ratio'
        }

        for yf_field, our_field in field_mapping.items():
            value = info.get(yf_field)
            if value is not None and value != 'N/A' and value != -99:
                data[our_field] = {'value': value, 'source': source}

        data['_last_updated'] = datetime.utcnow().isoformat()
        logger.info(f"[{ticker}] Retrieved {len(data)-1} fields from {source}")
        return data

    except Exception as e:
        logger.warning(f"[{ticker}] Failed to get data from {source}: {e}")
        return {}

# ==================== FALLBACK SOURCE 1: FMP API ====================
def fetch_fmp(ticker: str, existing_data: Dict[str, Any]) -> Dict[str, Any]:
    """Fetch missing data from Financial Modeling Prep API."""
    source = "fmp"
    fetched_data = {}
    try:
        logger.info(f"[{ticker}] Trying {source} fallback...")
        url = f"https://financialmodelingprep.com/api/v3/profile/{ticker}?apikey={FMP_API_KEY}"
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        company_data = response.json()

        if isinstance(company_data, list) and len(company_data) > 0:
            profile = company_data[0]
            
            # Only fetch missing fields
            fmp_field_mapping = {
                'priceEarningsToGrowthRatio': 'peg_ratio',
                'beta': 'beta',
                'priceToBook': 'price_to_book',
            }
            for fmp_field, our_field in fmp_field_mapping.items():
                if our_field not in existing_data and fmp_field in profile:
                    value = profile.get(fmp_field)
                    if value is not None:
                        fetched_data[our_field] = {'value': value, 'source': source}

        time.sleep(0.2)
        if fetched_data:
            logger.info(f"[{ticker}] Added {len(fetched_data)} fields from {source}")
        return fetched_data

    except requests.exceptions.RequestException as e:
        logger.warning(f"[{ticker}] Network error from {source}: {e}")
        return {}
    except Exception as e:
        logger.warning(f"[{ticker}] Failed to parse data from {source}: {e}")
        return {}

# ==================== FALLBACK SOURCE 2: Alpha Vantage ====================
def fetch_alpha_vantage(ticker: str, existing_data: Dict[str, Any]) -> Dict[str, Any]:
    """Fetch missing data from Alpha Vantage API (sparingly - 25 req/day limit)."""
    source = "alpha_vantage"
    fetched_data = {}
    try:
        # Only call if we're still missing PEG
        if 'peg_ratio' in existing_data:
            return {}

        logger.info(f"[{ticker}] Trying {source} for PEG ratio...")
        url = f"https://www.alphavantage.co/query"
        params = {
            'function': 'OVERVIEW',
            'symbol': ticker,
            'apikey': ALPHA_VANTAGE_API_KEY
        }
        response = requests.get(url, params=params, timeout=15)
        response.raise_for_status()
        overview_data = response.json()

        if "Error Message" in overview_data:
            logger.warning(f"[{ticker}] {source} returned error: {overview_data['Error Message']}")
            return {}

        # Extract PEG ratio
        if 'PEGRatio' in overview_data and overview_data['PEGRatio'] not in ('', 'None', None):
            value = overview_data.get('PEGRatio')
            try:
                fetched_data['peg_ratio'] = {'value': float(value), 'source': source}
                logger.info(f"[{ticker}] Found PEG ratio from {source}")
            except (ValueError, TypeError):
                pass

        time.sleep(15)  # Strict rate limiting (5 calls/min)
        return fetched_data

    except requests.exceptions.RequestException as e:
        logger.warning(f"[{ticker}] Network error from {source}: {e}")
        return {}
    except Exception as e:
        logger.warning(f"[{ticker}] Failed to parse data from {source}: {e}")
        return {}

# ==================== MASTER COLLECTOR FUNCTION ====================
def collect_fundamentals_multisource(ticker: str) -> Dict[str, Any]:
    """
    Multi-source collector with fallbacks: yfinance → FMP → Alpha Vantage
    Returns dict with all fields or N/A with source attribution.
    """
    all_data = {}
    logger.info(f"=== Starting collection for {ticker} ===")

    # 1. PRIMARY: yfinance
    all_data.update(fetch_yfinance(ticker))

    # 2. FALLBACK 1: FMP (for missing fields, especially PEG)
    missing_critical = any(field not in all_data for field in ['peg_ratio', 'trailing_pe'])
    if missing_critical:
        fmp_data = fetch_fmp(ticker, all_data)
        all_data.update(fmp_data)

    # 3. FALLBACK 2: Alpha Vantage (specifically for PEG if still missing)
    if 'peg_ratio' not in all_data:
        av_data = fetch_alpha_vantage(ticker, all_data)
        all_data.update(av_data)

    # 4. Ensure all expected fields exist
    expected_fields = [
        'market_cap', 'trailing_pe', 'forward_pe', 'peg_ratio',
        'short_pct', 'insider_pct', 'institution_pct', 'beta', 'price_to_book', 'price_to_sales'
    ]
    final_output = {'ticker': ticker}
    for field in expected_fields:
        final_output[field] = all_data.get(field, {'value': None, 'source': None})

    logger.info(f"=== Completed {ticker}. Fields found: {sum(1 for f in expected_fields if final_output[f]['value'] is not None)}/{len(expected_fields)} ===\n")
    return final_output

# ==================== TEST ON YOUR HOLDINGS ====================
print("✅ API Keys loaded:")
print(f"  FMP: ✓ (hardcoded)")
print(f"  Alpha Vantage: ✓ (hardcoded)\n")

print("🔄 Testing multi-source fundamentals collector on YOUR holdings...")
test_tickers_fund = ['IONQ', 'ASTS', 'HOOD', 'MARA', 'PLTR']
test_funds = []

for ticker in test_tickers_fund:
    print(f"\n  Processing {ticker}...")
    fund = collect_fundamentals_multisource(ticker)
    test_funds.append(fund)
    time.sleep(1)

# Flatten results for display
flat_results = []
for r in test_funds:
    flat_row = {'ticker': r['ticker']}
    for field in ['market_cap', 'trailing_pe', 'peg_ratio', 'short_pct', 'insider_pct', 'beta']:
        data = r.get(field, {})
        flat_row[f"{field}_value"] = data.get('value')
        flat_row[f"{field}_source"] = data.get('source')
    flat_results.append(flat_row)

fund_df = pd.DataFrame(flat_results)
print("\n📊 Results (with source attribution):")
print(fund_df)

# Summary
print("\n✅ Multi-source fundamentals scraper tested successfully!")
print(f"   Processed: {len(test_funds)} tickers")
print(f"   Fields per ticker: {sum(1 for f in ['market_cap', 'trailing_pe', 'peg_ratio', 'short_pct', 'insider_pct', 'beta'] if any(r.get(f, {}).get('value') is not None for r in test_funds))}/6")

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import json

class FundamentalDataBatchProcessor:
    """Batch processor with checkpointing for 353 tickers. Runs in 45-60 minutes."""
    
    def __init__(self, tickers, max_workers=5, checkpoint_interval=50):
        self.tickers = tickers
        self.max_workers = max_workers
        self.checkpoint_interval = checkpoint_interval
        self.results = []
        self.failed_tickers = []
        self.progress_file = "data/fundamentals_checkpoint.json"
        self.final_output_file = f"data/results/fundamentals_batch_{datetime.now().strftime('%Y%m%d_%H%M')}.csv"
        
        # Create directories if needed
        os.makedirs('data/results', exist_ok=True)

    def load_checkpoint(self):
        """Load previous progress from checkpoint file."""
        try:
            with open(self.progress_file, 'r') as f:
                saved = json.load(f)
                self.results = saved.get('results', [])
                processed_set = {r['ticker'] for r in self.results}
                # Only process new tickers
                self.tickers = [t for t in self.tickers if t not in processed_set]
                logger.info(f"Loaded checkpoint. {len(self.results)} already processed. {len(self.tickers)} remaining.")
        except FileNotFoundError:
            logger.info("No checkpoint found. Starting fresh.")
        except Exception as e:
            logger.error(f"Error loading checkpoint: {e}. Starting fresh.")

    def save_checkpoint(self):
        """Save current progress to checkpoint file."""
        try:
            checkpoint_data = {
                'timestamp': datetime.utcnow().isoformat(),
                'results': self.results,
                'failed': self.failed_tickers
            }
            with open(self.progress_file, 'w') as f:
                json.dump(checkpoint_data, f, indent=2)
            logger.info(f"Checkpoint saved. {len(self.results)} processed, {len(self.failed_tickers)} failed.")
        except Exception as e:
            logger.error(f"Failed to save checkpoint: {e}")

    def process_single(self, ticker: str):
        """Wrapper with retry logic (exponential backoff)."""
        max_retries = 3
        for attempt in range(max_retries):
            try:
                result = collect_fundamentals_multisource(ticker)
                return result
            except Exception as e:
                if attempt == max_retries - 1:
                    raise e
                wait_time = (2 ** attempt) + 1
                logger.warning(f"[{ticker}] Attempt {attempt+1} failed. Retrying in {wait_time}s.")
                time.sleep(wait_time)

    def run_batch(self):
        """Main batch processor with parallel execution and progress tracking."""
        logger.info(f"Starting batch processing for {len(self.tickers)} tickers with {self.max_workers} workers.")
        self.load_checkpoint()

        if len(self.tickers) == 0:
            logger.info("All tickers already processed!")
            self.save_results_to_csv(0)
            return

        total = len(self.tickers)
        processed = 0
        start_time = time.time()

        with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
            future_to_ticker = {executor.submit(self.process_single, ticker): ticker for ticker in self.tickers}

            for future in as_completed(future_to_ticker):
                ticker = future_to_ticker[future]
                try:
                    result = future.result(timeout=60)
                    self.results.append(result)
                    processed += 1

                    # Progress every 10 tickers
                    if processed % 10 == 0:
                        elapsed = time.time() - start_time
                        eta = (elapsed / processed) * (total - processed) if processed > 0 else 0
                        logger.info(f"Progress: {processed}/{total} ({processed/total:.1%}). ETA: {eta/60:.1f} min.")

                    # Checkpoint every 50 tickers
                    if processed % self.checkpoint_interval == 0:
                        self.save_checkpoint()

                except Exception as e:
                    logger.error(f"Error processing {ticker}: {e}")
                    self.failed_tickers.append({'ticker': ticker, 'error': str(e)})

        elapsed_total = time.time() - start_time
        self.save_results_to_csv(elapsed_total)
        self.save_checkpoint()
        self.print_summary(elapsed_total)

    def save_results_to_csv(self, elapsed_time):
        """Flatten and save results to CSV with source attribution."""
        if not self.results:
            logger.warning("No results to save.")
            return

        flat_rows = []
        for r in self.results:
            flat_row = {'ticker': r['ticker']}
            for field in ['market_cap', 'trailing_pe', 'forward_pe', 'peg_ratio',
                          'short_pct', 'insider_pct', 'institution_pct', 'beta', 'price_to_book', 'price_to_sales']:
                data = r.get(field, {})
                flat_row[f"{field}_value"] = data.get('value')
                flat_row[f"{field}_source"] = data.get('source')
            flat_rows.append(flat_row)

        df = pd.DataFrame(flat_rows)
        
        # Add metadata
        metadata = (
            f"# Generated: {datetime.utcnow().isoformat()}\n"
            f"# Total tickers: {len(self.results) + len(self.failed_tickers)}\n"
            f"# Successfully processed: {len(self.results)}\n"
            f"# Failed: {len(self.failed_tickers)}\n"
            f"# Processing time: {elapsed_time:.1f} seconds ({elapsed_time/60:.1f} minutes)\n"
            f"# Success rate: {len(self.results)/(len(self.results)+len(self.failed_tickers)):.1%}\n"
        )

        with open(self.final_output_file, 'w') as f:
            f.write(metadata)
            df.to_csv(f, index=False)

        logger.info(f"Results saved to {self.final_output_file}")

    def print_summary(self, elapsed_time):
        """Print final summary report."""
        print("\n" + "="*60)
        print("BATCH PROCESSING SUMMARY")
        print("="*60)
        print(f"Total tickers attempted: {len(self.results) + len(self.failed_tickers)}")
        print(f"Successfully processed:  {len(self.results)}")
        print(f"Failed:                  {len(self.failed_tickers)}")
        print(f"Total time:              {elapsed_time/60:.1f} minutes")
        if len(self.results) + len(self.failed_tickers) > 0:
            success_rate = len(self.results)/(len(self.results) + len(self.failed_tickers))
            print(f"Success rate:            {success_rate:.1%}")
        print("="*60)

# ==================== RUN ON ALL 353 TICKERS ====================
# UNCOMMENT BELOW TO RUN FULL BATCH (will take 45-60 minutes)

print("⚠️ Full batch processing: 353 tickers, 45-60 minutes")
print("   Checkpoints saved every 50 tickers for recovery\n")

# Uncomment to run:
# processor = FundamentalDataBatchProcessor(
#     tickers=TICKERS,
#     max_workers=5,
#     checkpoint_interval=50
# )
# processor.run_batch()

# For now, test on 20 tickers to validate:
print("🔄 Testing batch processor on first 20 tickers...")
processor = FundamentalDataBatchProcessor(
    tickers=TICKERS[:20],
    max_workers=3,
    checkpoint_interval=50
)
processor.run_batch()
print("\n✅ Batch processor test complete!")

# %%
def get_sec_insider_trades(ticker):
    """
    Get insider trading data from SEC EDGAR using their JSON API
    100% free, no API key needed
    """
    try:
        # Step 1: Get CIK (company ID) from ticker
        cik_lookup_url = "https://www.sec.gov/files/company_tickers.json"
        cik_data = requests.get(cik_lookup_url, headers=HEADERS, timeout=10).json()
        
        cik = None
        for entry in cik_data.values():
            if entry['ticker'].upper() == ticker.upper():
                cik = str(entry['cik_str']).zfill(10)  # Pad with zeros
                break
        
        if not cik:
            return {'ticker': ticker, 'insider_trades': 0, 'recent_filings': []}
        
        # Step 2: Get filing history from SEC
        filing_url = f"https://data.sec.gov/submissions/CIK{cik}.json"
        filing_data = requests.get(filing_url, headers=HEADERS, timeout=10).json()
        
        # Step 3: Filter for Form 4 (insider trades) and 8-K (major events)
        filings_df = pd.DataFrame(filing_data['filings']['recent'])
        insider_filings = filings_df[filings_df['form'].isin(['4', '8-K'])].head(10)
        
        recent_trades = []
        for _, filing in insider_filings.iterrows():
            recent_trades.append({
                'date': filing['filingDate'],
                'form': filing['form'],
                'description': filing.get('primaryDocDescription', 'N/A')
            })
        
        return {
            'ticker': ticker,
            'cik': cik,
            'insider_trades': len(insider_filings[insider_filings['form'] == '4']),
            'recent_filings': recent_trades
        }
        
    except Exception as e:
        return {'ticker': ticker, 'error': str(e), 'insider_trades': 0}

# Test on 3 tickers
print("🔄 Testing SEC insider scraper...")
test_insiders = []
for ticker in ['NVDA', 'IONQ', 'HOOD']:
    print(f"  Fetching {ticker} SEC filings...")
    insider = get_sec_insider_trades(ticker)
    test_insiders.append(insider)
    time.sleep(2)  # SEC rate limit

for ins in test_insiders:
    print(f"\n{ins['ticker']}: {ins.get('insider_trades', 0)} recent Form 4 filings")
    if 'recent_filings' in ins:
        for filing in ins['recent_filings'][:3]:
            print(f"  - {filing['date']} [{filing['form']}]")

# %%
def scrape_google_news(ticker, max_articles=5):
    """
    Scrape Google News RSS feed for ticker
    Free, no API key needed
    """
    url = f"https://news.google.com/rss/search?q={ticker}+stock&hl=en-US&gl=US&ceid=US:en"
    
    try:
        resp = requests.get(url, headers=HEADERS, timeout=10)
        soup = BeautifulSoup(resp.content, features='xml')
        
        news_items = []
        for item in soup.findAll('item')[:max_articles]:
            news_items.append({
                'ticker': ticker,
                'title': item.title.text if item.title else '',
                'published': item.pubDate.text if item.pubDate else '',
                'link': item.link.text if item.link else ''
            })
        
        return news_items
        
    except Exception as e:
        return [{'ticker': ticker, 'error': str(e)}]

# Test on 3 tickers
print("🔄 Testing Google News scraper...")
all_news = []
for ticker in ['NVDA', 'IONQ', 'TSLA']:
    print(f"  Fetching news for {ticker}...")
    news = scrape_google_news(ticker, max_articles=3)
    all_news.extend(news)
    time.sleep(1)

news_df = pd.DataFrame(all_news)
print(f"\n✅ Collected {len(news_df)} news articles")
print("\nSample headlines:")
for _, row in news_df.head(5).iterrows():
    if 'title' in row:
        print(f"  {row['ticker']}: {row['title'][:70]}...")

# %%
# Load FinBERT model for financial sentiment analysis
from transformers import pipeline

print("Loading FinBERT model for GPU sentiment analysis...")
device = 0 if torch.cuda.is_available() else -1
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model="ProsusAI/finbert",
    device=device,
    truncation=True,
    max_length=512
)

print(f"✅ Model loaded on {'GPU' if device == 0 else 'CPU'}")

# Test GPU speed
test_texts = [
    "Company reports record earnings with 50% revenue growth",
    "Stock plunges on disappointing guidance and regulatory concerns",
    "New product launch expected to drive significant market share gains"
]

start = time.time()
test_results = sentiment_pipeline(test_texts, batch_size=3)
elapsed = time.time() - start

print(f"\n⚡ GPU Speed Test: {len(test_texts)} texts in {elapsed:.3f}s ({len(test_texts)/elapsed:.1f} texts/sec)")
print("\nSample results:")
for text, result in zip(test_texts, test_results):
    print(f"  {result['label']}: {text[:50]}...")

# %%
# Install required packages (ensure safe, compatible versions)
# !pip install -q --upgrade pip
# !pip install -q "torch>=2.6" "transformers>=4.45" safetensors
# !pip install -q yfinance pandas numpy requests beautifulsoup4 lxml
# !pip install -q sentence-transformers
# !pip install -q matplotlib seaborn plotly

print("✅ Packages installed and upgraded (torch/transformers)")

# %%
# Install required packages (ensure safe, compatible versions)
# !pip install -q --upgrade pip
# !pip install -q "torch>=2.6" "transformers>=4.45" safetensors
# !pip install -q yfinance pandas numpy requests beautifulsoup4 lxml
# !pip install -q sentence-transformers
# !pip install -q matplotlib seaborn plotly

print("✅ Packages installed and upgraded (torch/transformers)")
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1+cu121, but you have torch 2.9.1 which is incompatible.
# torchvision 0.20.1+cu121 requires torch==2.5.1+cu121, but you have torch 2.9.1 which is incompatible.
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# ✅ Packages installed and upgraded (torch/transformers)

# %%
# Install required packages (ensure safe, compatible versions)
# !pip install -q --upgrade pip
# !pip install -q "torch>=2.6" "transformers>=4.45" safetensors
# !pip install -q yfinance pandas numpy requests beautifulsoup4 lxml
# !pip install -q sentence-transformers
# !pip install -q matplotlib seaborn plotly

print("✅ Packages installed and upgraded (torch/transformers)")
# Out:
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# ✅ Packages installed and upgraded (torch/transformers)

# %%
# Install required packages (ensure safe, compatible versions)
# !pip install -q --upgrade pip

# Recover from broken sympy uninstall state (missing RECORD file)
# !pip install -q --force-reinstall --no-deps sympy==1.13.1

# Core ML + safety
# !pip install -q "torch>=2.6" "transformers>=4.45" safetensors

# Data + scraping
# !pip install -q yfinance pandas numpy requests beautifulsoup4 lxml
# !pip install -q sentence-transformers
# !pip install -q matplotlib seaborn plotly

print("✅ Packages installed and upgraded (torch/transformers); sympy recovered")
# Out:
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# ✅ Packages installed and upgraded (torch/transformers); sympy recovered

# %%
# Install required packages (ensure safe, compatible versions)
# !pip install -q --upgrade pip

# Recover from broken sympy uninstall state (missing RECORD file)
# !pip install -q --force-reinstall --no-deps sympy==1.13.1

# Core ML + safety
# !pip install -q "torch>=2.6" "transformers>=4.45" safetensors

# Data + scraping
# !pip install -q yfinance pandas numpy requests beautifulsoup4 lxml
# !pip install -q sentence-transformers
# !pip install -q matplotlib seaborn plotly

print("✅ Packages installed and upgraded (torch/transformers); sympy recovered")
# Out:
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# ✅ Packages installed and upgraded (torch/transformers); sympy recovered

# %%
# Install required packages (ensure safe, compatible versions)
# !pip install -q --upgrade pip

# Recover from broken sympy uninstall state (missing RECORD file)
# Try force-reinstall; if pip still complains, fallback to ignore-installed.
# !python -m pip install -q --force-reinstall --no-deps sympy==1.13.1 || python -m pip install -q --ignore-installed --no-deps sympy==1.13.1

# Core ML + safety
# !pip install -q "torch>=2.6" "transformers>=4.45" safetensors

# Data + scraping
# !pip install -q yfinance pandas numpy requests beautifulsoup4 lxml
# !pip install -q sentence-transformers
# !pip install -q matplotlib seaborn plotly

print("✅ Packages installed; sympy repaired via reinstall/ignore-installed")
# Out:
# error: uninstall-no-record-file
#
# Cannot uninstall sympy None
#
# The package's contents are unknown: no RECORD file was found for sympy.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps sympy==1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1+cu121, but you have torch 2.9.1 which is incompatible.
# torchvision 0.20.1+cu121 requires torch==2.5.1+cu121, but you have torch 2.9.1 which is incompatible.
# ✅ Packages installed; sympy repaired via reinstall/ignore-installed

# %%
# Install required packages with GPU support
# !pip install -q --upgrade pip

# CRITICAL: Remove broken sympy first (bypass metadata corruption)
# !pip uninstall -y sympy 2>/dev/null || echo "Sympy not found, continuing..."
# !rm -rf /usr/local/lib/python*/site-packages/sympy* 2>/dev/null || echo "Manual cleanup done"

# Uninstall incompatible torch versions to start fresh
# !pip uninstall -y torch torchvision torchaudio -q 2>/dev/null || echo "Torch cleanup done"

# Install PyTorch with CUDA 12.1 support (for GPU acceleration)
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# Upgrade transformers + safetensors for FinBERT compatibility
# !pip install -q --upgrade "transformers>=4.45" safetensors

# Data + scraping stack
# !pip install -q yfinance pandas numpy requests beautifulsoup4 lxml
# !pip install -q sentence-transformers matplotlib seaborn plotly

# Install sympy last with ignore-installed (if needed by dependencies)
# !pip install -q --ignore-installed --no-deps sympy 2>/dev/null || echo "Sympy skipped (not critical)"

print("✅ All packages installed with CUDA support")
print("✅ GPU should now be available - verify in next cell")
# Out:
# "Sympy not found, continuing..."
# The system cannot find the path specified.
# "Manual cleanup done"
# The system cannot find the path specified.
# "Torch cleanup done"
# The system cannot find the path specified.
# "Sympy skipped (not critical)"
# ✅ All packages installed with CUDA support
# ✅ GPU should now be available - verify in next cell
# The system cannot find the path specified.

# %%
# Install required packages with GPU support (cross-platform: Windows/Linux)
import subprocess
import sys
import shutil
from pathlib import Path

print("🔄 Starting installation (cross-platform)...")

# Step 1: Upgrade pip
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "--upgrade", "pip"])

# Step 2: Remove broken sympy (Python cross-platform method)
print("🧹 Cleaning sympy...")
try:
    subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "sympy"], 
                   capture_output=True, check=False)
    # Manual cleanup of sympy directories
    for site_pkg in Path(sys.prefix).rglob("site-packages"):
        for sympy_dir in site_pkg.glob("sympy*"):
            shutil.rmtree(sympy_dir, ignore_errors=True)
            print(f"  Removed: {sympy_dir.name}")
except Exception as e:
    print(f"  Sympy cleanup: {e}")

# Step 3: Remove old torch versions to avoid conflicts
print("🧹 Cleaning old PyTorch...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", 
                "torch", "torchvision", "torchaudio"], 
               capture_output=True, check=False)

# Step 4: Install PyTorch with CUDA 12.1 (GPU support)
print("🚀 Installing PyTorch with CUDA 12.1...")
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "-q",
    "torch", "torchvision", "torchaudio",
    "--index-url", "https://download.pytorch.org/whl/cu121"
])

# Step 5: Install transformers + safetensors for FinBERT
print("🤖 Installing transformers...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", 
                       "--upgrade", "transformers>=4.45", "safetensors"])

# Step 6: Data processing and scraping stack
print("📊 Installing data packages...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q",
                       "yfinance", "pandas", "numpy", "requests", 
                       "beautifulsoup4", "lxml"])

print("🧠 Installing ML packages...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q",
                       "sentence-transformers", "matplotlib", "seaborn", "plotly"])

# Step 7: Install sympy last (ignore broken metadata)
print("🔢 Installing sympy...")
subprocess.run([sys.executable, "-m", "pip", "install", "-q", 
                "--ignore-installed", "--no-deps", "sympy"], 
               capture_output=True, check=False)

print("\n✅ All packages installed!")
print("✅ GPU-enabled PyTorch installed (CUDA 12.1)")
print("🔍 Verify GPU detection in next cell...")
# Out:
# 🔄 Starting installation (cross-platform)...
# 🧹 Cleaning sympy...
# 🧹 Cleaning old PyTorch...
# 🚀 Installing PyTorch with CUDA 12.1...
# 🤖 Installing transformers...
# 📊 Installing data packages...
# 🧠 Installing ML packages...
# 🔢 Installing sympy...
#
# ✅ All packages installed!
# ✅ GPU-enabled PyTorch installed (CUDA 12.1)
# 🔍 Verify GPU detection in next cell...

# %%
# Install required packages with GPU support (cross-platform: Windows/Linux)
import subprocess
import sys
import shutil
from pathlib import Path

print("🔄 Starting installation (cross-platform)...")

# Step 1: Upgrade pip
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "--upgrade", "pip"])

# Step 2: Remove broken sympy (Python cross-platform method)
print("🧹 Cleaning sympy...")
try:
    subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "sympy"], 
                   capture_output=True, check=False)
    # Manual cleanup of sympy directories
    for site_pkg in Path(sys.prefix).rglob("site-packages"):
        for sympy_dir in site_pkg.glob("sympy*"):
            shutil.rmtree(sympy_dir, ignore_errors=True)
            print(f"  Removed: {sympy_dir.name}")
except Exception as e:
    print(f"  Sympy cleanup: {e}")

# Step 3: Remove old torch versions to avoid conflicts
print("🧹 Cleaning old PyTorch...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", 
                "torch", "torchvision", "torchaudio"], 
               capture_output=True, check=False)

# Step 4: Install PyTorch with CUDA 12.1 (GPU support)
print("🚀 Installing PyTorch with CUDA 12.1...")
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "-q",
    "torch", "torchvision", "torchaudio",
    "--index-url", "https://download.pytorch.org/whl/cu121"
])

# Step 5: Install transformers + safetensors for FinBERT
print("🤖 Installing transformers...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", 
                       "--upgrade", "transformers>=4.45", "safetensors"])

# Step 6: Data processing and scraping stack
print("📊 Installing data packages...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q",
                       "yfinance", "pandas", "numpy", "requests", 
                       "beautifulsoup4", "lxml"])

print("🧠 Installing ML packages...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q",
                       "sentence-transformers", "matplotlib", "seaborn", "plotly"])

# Step 7: Install sympy last (ignore broken metadata)
print("🔢 Installing sympy...")
subprocess.run([sys.executable, "-m", "pip", "install", "-q", 
                "--ignore-installed", "--no-deps", "sympy"], 
               capture_output=True, check=False)

print("\n✅ All packages installed!")
print("✅ GPU-enabled PyTorch installed (CUDA 12.1)")
print("🔍 Verify GPU detection in next cell...")
# Out:
# 🔄 Starting installation (cross-platform)...
# 🧹 Cleaning sympy...
#   Removed: sympy
#   Removed: sympy-1.14.0.dist-info
# 🧹 Cleaning old PyTorch...
# 🚀 Installing PyTorch with CUDA 12.1...
# 🤖 Installing transformers...
# 📊 Installing data packages...
# 🧠 Installing ML packages...
# 🔢 Installing sympy...
#
# ✅ All packages installed!
# ✅ GPU-enabled PyTorch installed (CUDA 12.1)
# 🔍 Verify GPU detection in next cell...

# %%
# Install required packages with GPU support (cross-platform: Windows/Linux)
import subprocess
import sys
import shutil
from pathlib import Path

print("🔄 Starting installation (cross-platform)...")

# Step 1: Upgrade pip
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "--upgrade", "pip"])

# Step 2: Remove broken sympy (Python cross-platform method)
print("🧹 Cleaning sympy...")
try:
    subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "sympy"], 
                   capture_output=True, check=False)
    # Manual cleanup of sympy directories
    for site_pkg in Path(sys.prefix).rglob("site-packages"):
        for sympy_dir in site_pkg.glob("sympy*"):
            shutil.rmtree(sympy_dir, ignore_errors=True)
            print(f"  Removed: {sympy_dir.name}")
except Exception as e:
    print(f"  Sympy cleanup: {e}")

# Step 3: Remove old torch versions to avoid conflicts
print("🧹 Cleaning old PyTorch...")
subprocess.run([sys.executable, "-m", "pip", "uninstall", "-y", "-q", 
                "torch", "torchvision", "torchaudio"], 
               capture_output=True, check=False)

# Step 4: Install PyTorch with CUDA 12.1 (GPU support)
print("🚀 Installing PyTorch with CUDA 12.1...")
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "-q",
    "torch", "torchvision", "torchaudio",
    "--index-url", "https://download.pytorch.org/whl/cu121"
])

# Step 5: Install transformers + safetensors for FinBERT
print("🤖 Installing transformers...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", 
                       "--upgrade", "transformers>=4.45", "safetensors"])

# Step 6: Data processing and scraping stack
print("📊 Installing data packages...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q",
                       "yfinance", "pandas", "numpy", "requests", 
                       "beautifulsoup4", "lxml"])

print("🧠 Installing ML packages...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-q",
                       "sentence-transformers", "matplotlib", "seaborn", "plotly"])

# Step 7: Install sympy last (ignore broken metadata)
print("🔢 Installing sympy...")
subprocess.run([sys.executable, "-m", "pip", "install", "-q", 
                "--ignore-installed", "--no-deps", "sympy"], 
               capture_output=True, check=False)

print("\n✅ All packages installed!")
print("✅ GPU-enabled PyTorch installed (CUDA 12.1)")
print("🔍 Verify GPU detection in next cell...")
# Out:
# 🔄 Starting installation (cross-platform)...
# 🧹 Cleaning sympy...
#   Removed: sympy
#   Removed: sympy-1.14.0.dist-info
# 🧹 Cleaning old PyTorch...
# 🚀 Installing PyTorch with CUDA 12.1...
# 🤖 Installing transformers...
# 📊 Installing data packages...
# 🧠 Installing ML packages...
# 🔢 Installing sympy...
#
# ✅ All packages installed!
# ✅ GPU-enabled PyTorch installed (CUDA 12.1)
# 🔍 Verify GPU detection in next cell...

# %%
# Import all libraries
import pandas as pd
import numpy as np
import yfinance as yf
import requests
from bs4 import BeautifulSoup
import time
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# GPU check
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("⚠️ Running on CPU")

print("\n✅ All imports successful")
# Out:
# PyTorch: 2.5.1+cu121
# CUDA available: True
# GPU: NVIDIA RTX 2000 Ada Generation
# GPU Memory: 16.1 GB
#
# ✅ All imports successful

# %%
# Browser headers (crucial for scraping)
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# Auto-detect environment and set paths
import os
import sys

# Check if running in Codespace (Linux) or local (Windows/Mac)
if os.path.exists('/workspaces/quantum-ai-trader_v1.1'):
    # Codespace environment
    WORKSPACE_ROOT = '/workspaces/quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'):
    # Shadow PC (original path)
    WORKSPACE_ROOT = r'C:\Users\alexj\Desktop\shadow_ai\quantum-ai-trader_v1.1'
elif os.path.exists(r'C:\Users\Shadow\quantum-ai-trader_v1.1'):
    # Shadow PC (alternate path)
    WORKSPACE_ROOT = r'C:\Users\Shadow\quantum-ai-trader_v1.1'
else:
    # Try relative path from notebook location
    notebook_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
    WORKSPACE_ROOT = os.path.abspath(os.path.join(notebook_dir, '..'))

DATA_DIR = os.path.join(WORKSPACE_ROOT, 'data')
UNIVERSE_FILE = os.path.join(DATA_DIR, 'ticker_universe_300.csv')
OUTPUT_FILE = os.path.join(DATA_DIR, 'research_results_top50.csv')

# Verify paths exist
print(f"✅ Workspace: {WORKSPACE_ROOT}")
print(f"✅ Data directory: {DATA_DIR}")
print(f"✅ Universe file: {UNIVERSE_FILE}")
print(f"✅ File exists: {os.path.exists(UNIVERSE_FILE)}")

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)
    print(f"📁 Created data directory")
# Out:
# ✅ Workspace: C:\Users\Shadow\quantum-ai-trader_v1.1
# ✅ Data directory: C:\Users\Shadow\quantum-ai-trader_v1.1\data
# ✅ Universe file: C:\Users\Shadow\quantum-ai-trader_v1.1\data\ticker_universe_300.csv
# ✅ File exists: True

# %%
# IF FILE DOESN'T EXIST: Download from GitHub or create sample
if not os.path.exists(UNIVERSE_FILE):
    print("⚠️ Universe file not found. Creating sample...")
    
    # Option 1: Try to download from GitHub
    import requests
    try:
        url = "https://raw.githubusercontent.com/alexpayne556-collab/quantum-ai-trader_v1.1/main/data/ticker_universe_300.csv"
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            with open(UNIVERSE_FILE, 'wb') as f:
                f.write(response.content)
            print(f"✅ Downloaded from GitHub to {UNIVERSE_FILE}")
        else:
            raise Exception("GitHub download failed")
    except:
        # Option 2: Create minimal sample for testing
        print("⚠️ Creating minimal sample (replace with full list later)")
        sample_tickers = [
            ('AAPL', 'Technology', 'Consumer Electronics', 'Large Cap', 'Benchmark'),
            ('NVDA', 'Technology', 'Semiconductors', 'Large Cap', 'AI Leader'),
            ('IONQ', 'Technology', 'Quantum Computing', 'Small Cap', 'Current Holding'),
            ('ASTS', 'Communications', 'Space', 'Small Cap', 'Current Holding'),
            ('HOOD', 'Fintech', 'Brokerage', 'Mid Cap', 'Current Holding'),
            ('MARA', 'Crypto', 'Bitcoin Mining', 'Small Cap', 'Mining Leader'),
            ('PLTR', 'Technology', 'Software', 'Mid Cap', 'AI/Data'),
            ('TSLA', 'Automotive', 'Electric Vehicles', 'Large Cap', 'Innovation'),
            ('AMD', 'Technology', 'Semiconductors', 'Large Cap', 'AI/GPU'),
            ('SOFI', 'Fintech', 'Banking', 'Small Cap', 'Digital Bank'),
        ]
        import pandas as pd
        df = pd.DataFrame(sample_tickers, columns=['ticker', 'sector', 'industry', 'market_cap_category', 'notes'])
        df.to_csv(UNIVERSE_FILE, index=False)
        print(f"✅ Created sample file: {UNIVERSE_FILE}")
        print("⚠️ IMPORTANT: Replace this with your full 353-ticker list!")
else:
    print("✅ Universe file found")
# Out:
# ✅ Universe file found

# %%
# Load 300-ticker universe
universe_df = pd.read_csv(UNIVERSE_FILE)

print(f"📊 Loaded {len(universe_df)} tickers\n")
print("Sector breakdown:")
print(universe_df['sector'].value_counts())
print("\nFirst 10 tickers:")
print(universe_df.head(10))
# Out:
# 📊 Loaded 353 tickers
#
# Sector breakdown:
# sector
# Healthcare        118
# Technology         85
# Energy             30
# E-commerce         16
# Retail             15
# Aerospace          15
# Automotive         14
# Materials          12
# Fintech             8
# Consumer            8
# Crypto              8
# Transportation      6
# Gaming              5
# Communications      5
# Industrials         5
# Travel              3
# Name: count, dtype: int64
#
# First 10 tickers:
#   ticker      sector              industry market_cap_category  \
# 0   AAPL  Technology  Consumer Electronics           Large Cap
# 1   MSFT  Technology              Software           Large Cap
# 2   NVDA  Technology        Semiconductors           Large Cap
# 3    AMD  Technology        Semiconductors           Large Cap
# 4   AVGO  Technology        Semiconductors           Large Cap
# 5   MSTR  Technology              Software             Mid Cap
# 6   IONQ  Technology     Quantum Computing           Small Cap
# 7  GOOGL  Technology              Internet           Large Cap
# 8   META  Technology          Social Media           Large Cap
# 9   TSLA  Automotive     Electric Vehicles           Large Cap
#
#                notes
# 0          Benchmark
# 1          Benchmark
# 2          AI Leader
# 3             AI/GPU
# 4         Networking
# 5      Bitcoin Proxy
# 6    Current Holding
# 7           AI/Cloud
# 8      AI Investment
# 9  Innovation Leader

# %%
def collect_ohlcv_batch(tickers, period='2y', batch_size=50):
    """
    Collect OHLCV data using yfinance (unlimited, free)
    Batch processing to avoid memory issues
    """
    all_data = {}
    failed = []
    
    for i in range(0, len(tickers), batch_size):
        batch = tickers[i:i+batch_size]
        print(f"Fetching batch {i//batch_size + 1} ({len(batch)} tickers)...")
        
        try:
            # Download batch (yfinance handles multiple tickers efficiently)
            data = yf.download(batch, period=period, group_by='ticker', 
                             progress=False, threads=True)
            
            # Store each ticker's data
            for ticker in batch:
                try:
                    if len(batch) == 1:
                        ticker_data = data
                    else:
                        ticker_data = data[ticker]
                    
                    if not ticker_data.empty and len(ticker_data) > 20:
                        all_data[ticker] = ticker_data
                    else:
                        failed.append(ticker)
                except:
                    failed.append(ticker)
            
            time.sleep(0.5)  # Polite delay
            
        except Exception as e:
            print(f"  Error in batch: {e}")
            failed.extend(batch)
    
    print(f"\n✅ Collected: {len(all_data)}/{len(tickers)} tickers")
    if failed:
        print(f"❌ Failed: {len(failed)} tickers - {failed[:10]}")
    
    return all_data, failed

# Test with first 20 tickers
print("🔄 Testing OHLCV collection with 20 tickers...")
test_tickers = TICKERS[:20]
ohlcv_data, failed_tickers = collect_ohlcv_batch(test_tickers, period='1y')

# Show sample
if ohlcv_data:
    sample_ticker = list(ohlcv_data.keys())[0]
    print(f"\nSample data for {sample_ticker}:")
    print(ohlcv_data[sample_ticker].tail())
# Out:
# 🔄 Testing OHLCV collection with 20 tickers...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 47
#      45 # Test with first 20 tickers
#      46 print("🔄 Testing OHLCV collection with 20 tickers...")
# ---> 47 test_tickers = TICKERS[:20]
#      48 ohlcv_data, failed_tickers = collect_ohlcv_batch(test_tickers, period='1y')
#      50 # Show sample
#
# NameError: name 'TICKERS' is not defined

# %%
# Get ticker list
TICKERS = universe_df['ticker'].tolist()

print(f"✅ {len(TICKERS)} tickers ready for analysis")
print(f"\nSample: {TICKERS[:20]}")
# Out:
# ✅ 353 tickers ready for analysis
#
# Sample: ['AAPL', 'MSFT', 'NVDA', 'AMD', 'AVGO', 'MSTR', 'IONQ', 'GOOGL', 'META', 'TSLA', 'PLTR', 'SNOW', 'CRWD', 'DDOG', 'NET', 'PANW', 'ZS', 'S', 'MDB', 'ESTC']

# %%
def collect_ohlcv_batch(tickers, period='2y', batch_size=50):
    """
    Collect OHLCV data using yfinance (unlimited, free)
    Batch processing to avoid memory issues
    """
    all_data = {}
    failed = []
    
    for i in range(0, len(tickers), batch_size):
        batch = tickers[i:i+batch_size]
        print(f"Fetching batch {i//batch_size + 1} ({len(batch)} tickers)...")
        
        try:
            # Download batch (yfinance handles multiple tickers efficiently)
            data = yf.download(batch, period=period, group_by='ticker', 
                             progress=False, threads=True)
            
            # Store each ticker's data
            for ticker in batch:
                try:
                    if len(batch) == 1:
                        ticker_data = data
                    else:
                        ticker_data = data[ticker]
                    
                    if not ticker_data.empty and len(ticker_data) > 20:
                        all_data[ticker] = ticker_data
                    else:
                        failed.append(ticker)
                except:
                    failed.append(ticker)
            
            time.sleep(0.5)  # Polite delay
            
        except Exception as e:
            print(f"  Error in batch: {e}")
            failed.extend(batch)
    
    print(f"\n✅ Collected: {len(all_data)}/{len(tickers)} tickers")
    if failed:
        print(f"❌ Failed: {len(failed)} tickers - {failed[:10]}")
    
    return all_data, failed

# Test with first 20 tickers
print("🔄 Testing OHLCV collection with 20 tickers...")
test_tickers = TICKERS[:20]
ohlcv_data, failed_tickers = collect_ohlcv_batch(test_tickers, period='1y')

# Show sample
if ohlcv_data:
    sample_ticker = list(ohlcv_data.keys())[0]
    print(f"\nSample data for {sample_ticker}:")
    print(ohlcv_data[sample_ticker].tail())
# Out:
# 🔄 Testing OHLCV collection with 20 tickers...
# Fetching batch 1 (20 tickers)...
#
# ✅ Collected: 20/20 tickers
#
# Sample data for AAPL:
# Price             Open        High         Low       Close    Volume
# Date
# 2025-12-08  278.130005  279.670013  276.149994  277.890015  38211800
# 2025-12-09  278.160004  280.029999  276.920013  277.179993  32193300
# 2025-12-10  277.750000  279.750000  276.440002  278.779999  33038300
# 2025-12-11  279.100006  279.589996  273.809998  278.029999  33248000
# 2025-12-12  277.795013  279.220001  276.820007  278.279999  39532887

# %%
import logging
from typing import Dict, Any, Optional
from datetime import datetime

# ==================== HARDCODED API KEYS ====================
FMP_API_KEY = "15zYYtksuJnQsTBODSNs3MrfEedOSd3i"
ALPHA_VANTAGE_API_KEY = "0ROKR956QR1XHDLZ"

# ==================== CONFIGURE LOGGING ====================
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[logging.FileHandler('data/fundamentals_collector.log'),
                              logging.StreamHandler()])
logger = logging.getLogger(__name__)

# ==================== PRIMARY SOURCE: yfinance ====================
def fetch_yfinance(ticker: str) -> Dict[str, Any]:
    """Fetch data from yfinance. Returns dict with source attribution."""
    data = {}
    source = "yfinance"
    try:
        stock = yf.Ticker(ticker)
        info = stock.info

        # Map yfinance fields to standardized names
        field_mapping = {
            'marketCap': 'market_cap',
            'trailingPE': 'trailing_pe',
            'forwardPE': 'forward_pe',
            'shortPercentOfFloat': 'short_pct',
            'heldPercentInsiders': 'insider_pct',
            'heldPercentInstitutions': 'institution_pct',
            'beta': 'beta',
            'priceToBook': 'price_to_book',
            'priceToSalesTrailing12Months': 'price_to_sales',
            'pegRatio': 'peg_ratio'
        }

        for yf_field, our_field in field_mapping.items():
            value = info.get(yf_field)
            if value is not None and value != 'N/A' and value != -99:
                data[our_field] = {'value': value, 'source': source}

        data['_last_updated'] = datetime.utcnow().isoformat()
        logger.info(f"[{ticker}] Retrieved {len(data)-1} fields from {source}")
        return data

    except Exception as e:
        logger.warning(f"[{ticker}] Failed to get data from {source}: {e}")
        return {}

# ==================== FALLBACK SOURCE 1: FMP API ====================
def fetch_fmp(ticker: str, existing_data: Dict[str, Any]) -> Dict[str, Any]:
    """Fetch missing data from Financial Modeling Prep API."""
    source = "fmp"
    fetched_data = {}
    try:
        logger.info(f"[{ticker}] Trying {source} fallback...")
        url = f"https://financialmodelingprep.com/api/v3/profile/{ticker}?apikey={FMP_API_KEY}"
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        company_data = response.json()

        if isinstance(company_data, list) and len(company_data) > 0:
            profile = company_data[0]
            
            # Only fetch missing fields
            fmp_field_mapping = {
                'priceEarningsToGrowthRatio': 'peg_ratio',
                'beta': 'beta',
                'priceToBook': 'price_to_book',
            }
            for fmp_field, our_field in fmp_field_mapping.items():
                if our_field not in existing_data and fmp_field in profile:
                    value = profile.get(fmp_field)
                    if value is not None:
                        fetched_data[our_field] = {'value': value, 'source': source}

        time.sleep(0.2)
        if fetched_data:
            logger.info(f"[{ticker}] Added {len(fetched_data)} fields from {source}")
        return fetched_data

    except requests.exceptions.RequestException as e:
        logger.warning(f"[{ticker}] Network error from {source}: {e}")
        return {}
    except Exception as e:
        logger.warning(f"[{ticker}] Failed to parse data from {source}: {e}")
        return {}

# ==================== FALLBACK SOURCE 2: Alpha Vantage ====================
def fetch_alpha_vantage(ticker: str, existing_data: Dict[str, Any]) -> Dict[str, Any]:
    """Fetch missing data from Alpha Vantage API (sparingly - 25 req/day limit)."""
    source = "alpha_vantage"
    fetched_data = {}
    try:
        # Only call if we're still missing PEG
        if 'peg_ratio' in existing_data:
            return {}

        logger.info(f"[{ticker}] Trying {source} for PEG ratio...")
        url = f"https://www.alphavantage.co/query"
        params = {
            'function': 'OVERVIEW',
            'symbol': ticker,
            'apikey': ALPHA_VANTAGE_API_KEY
        }
        response = requests.get(url, params=params, timeout=15)
        response.raise_for_status()
        overview_data = response.json()

        if "Error Message" in overview_data:
            logger.warning(f"[{ticker}] {source} returned error: {overview_data['Error Message']}")
            return {}

        # Extract PEG ratio
        if 'PEGRatio' in overview_data and overview_data['PEGRatio'] not in ('', 'None', None):
            value = overview_data.get('PEGRatio')
            try:
                fetched_data['peg_ratio'] = {'value': float(value), 'source': source}
                logger.info(f"[{ticker}] Found PEG ratio from {source}")
            except (ValueError, TypeError):
                pass

        time.sleep(15)  # Strict rate limiting (5 calls/min)
        return fetched_data

    except requests.exceptions.RequestException as e:
        logger.warning(f"[{ticker}] Network error from {source}: {e}")
        return {}
    except Exception as e:
        logger.warning(f"[{ticker}] Failed to parse data from {source}: {e}")
        return {}

# ==================== MASTER COLLECTOR FUNCTION ====================
def collect_fundamentals_multisource(ticker: str) -> Dict[str, Any]:
    """
    Multi-source collector with fallbacks: yfinance → FMP → Alpha Vantage
    Returns dict with all fields or N/A with source attribution.
    """
    all_data = {}
    logger.info(f"=== Starting collection for {ticker} ===")

    # 1. PRIMARY: yfinance
    all_data.update(fetch_yfinance(ticker))

    # 2. FALLBACK 1: FMP (for missing fields, especially PEG)
    missing_critical = any(field not in all_data for field in ['peg_ratio', 'trailing_pe'])
    if missing_critical:
        fmp_data = fetch_fmp(ticker, all_data)
        all_data.update(fmp_data)

    # 3. FALLBACK 2: Alpha Vantage (specifically for PEG if still missing)
    if 'peg_ratio' not in all_data:
        av_data = fetch_alpha_vantage(ticker, all_data)
        all_data.update(av_data)

    # 4. Ensure all expected fields exist
    expected_fields = [
        'market_cap', 'trailing_pe', 'forward_pe', 'peg_ratio',
        'short_pct', 'insider_pct', 'institution_pct', 'beta', 'price_to_book', 'price_to_sales'
    ]
    final_output = {'ticker': ticker}
    for field in expected_fields:
        final_output[field] = all_data.get(field, {'value': None, 'source': None})

    logger.info(f"=== Completed {ticker}. Fields found: {sum(1 for f in expected_fields if final_output[f]['value'] is not None)}/{len(expected_fields)} ===\n")
    return final_output

# ==================== TEST ON YOUR HOLDINGS ====================
print("✅ API Keys loaded:")
print(f"  FMP: ✓ (hardcoded)")
print(f"  Alpha Vantage: ✓ (hardcoded)\n")

print("🔄 Testing multi-source fundamentals collector on YOUR holdings...")
test_tickers_fund = ['IONQ', 'ASTS', 'HOOD', 'MARA', 'PLTR']
test_funds = []

for ticker in test_tickers_fund:
    print(f"\n  Processing {ticker}...")
    fund = collect_fundamentals_multisource(ticker)
    test_funds.append(fund)
    time.sleep(1)

# Flatten results for display
flat_results = []
for r in test_funds:
    flat_row = {'ticker': r['ticker']}
    for field in ['market_cap', 'trailing_pe', 'peg_ratio', 'short_pct', 'insider_pct', 'beta']:
        data = r.get(field, {})
        flat_row[f"{field}_value"] = data.get('value')
        flat_row[f"{field}_source"] = data.get('source')
    flat_results.append(flat_row)

fund_df = pd.DataFrame(flat_results)
print("\n📊 Results (with source attribution):")
print(fund_df)

# Summary
print("\n✅ Multi-source fundamentals scraper tested successfully!")
print(f"   Processed: {len(test_funds)} tickers")
print(f"   Fields per ticker: {sum(1 for f in ['market_cap', 'trailing_pe', 'peg_ratio', 'short_pct', 'insider_pct', 'beta'] if any(r.get(f, {}).get('value') is not None for r in test_funds))}/6")
# Out:
# 2025-12-14 21:37:00,995 - INFO - === Starting collection for IONQ ===
# 2025-12-14 21:37:01,195 - INFO - [IONQ] Retrieved 8 fields from yfinance
# ✅ API Keys loaded:
#   FMP: ✓ (hardcoded)
#   Alpha Vantage: ✓ (hardcoded)
#
# 🔄 Testing multi-source fundamentals collector on YOUR holdings...
#
#   Processing IONQ...
# 2025-12-14 21:37:01,196 - INFO - [IONQ] Trying fmp fallback...
# 2025-12-14 21:37:01,487 - WARNING - [IONQ] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/IONQ?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 21:37:01,490 - INFO - [IONQ] Trying alpha_vantage for PEG ratio...
# 2025-12-14 21:37:17,164 - INFO - === Completed IONQ. Fields found: 8/10 ===
#
# 2025-12-14 21:37:18,165 - INFO - === Starting collection for ASTS ===
#   Processing ASTS...
# 2025-12-14 21:37:18,381 - INFO - [ASTS] Retrieved 8 fields from yfinance
# 2025-12-14 21:37:18,381 - INFO - [ASTS] Trying fmp fallback...
# 2025-12-14 21:37:18,601 - WARNING - [ASTS] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/ASTS?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 21:37:18,603 - INFO - [ASTS] Trying alpha_vantage for PEG ratio...
# 2025-12-14 21:37:34,654 - INFO - === Completed ASTS. Fields found: 8/10 ===
#
# 2025-12-14 21:37:35,655 - INFO - === Starting collection for HOOD ===
#   Processing HOOD...
# 2025-12-14 21:37:35,872 - INFO - [HOOD] Retrieved 9 fields from yfinance
# 2025-12-14 21:37:35,873 - INFO - [HOOD] Trying fmp fallback...
# 2025-12-14 21:37:36,085 - WARNING - [HOOD] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/HOOD?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 21:37:36,088 - INFO - [HOOD] Trying alpha_vantage for PEG ratio...
# 2025-12-14 21:37:52,023 - INFO - === Completed HOOD. Fields found: 9/10 ===
#
# 2025-12-14 21:37:53,024 - INFO - === Starting collection for MARA ===
# 2025-12-14 21:37:53,183 - INFO - [MARA] Retrieved 9 fields from yfinance
# 2025-12-14 21:37:53,183 - INFO - [MARA] Trying fmp fallback...
#   Processing MARA...
# 2025-12-14 21:37:53,415 - WARNING - [MARA] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/MARA?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 21:37:53,416 - INFO - [MARA] Trying alpha_vantage for PEG ratio...
# 2025-12-14 21:37:53,660 - INFO - [MARA] Found PEG ratio from alpha_vantage
# 2025-12-14 21:38:08,662 - INFO - === Completed MARA. Fields found: 10/10 ===
#
# 2025-12-14 21:38:09,663 - INFO - === Starting collection for PLTR ===
#   Processing PLTR...
# 2025-12-14 21:38:09,871 - INFO - [PLTR] Retrieved 9 fields from yfinance
# 2025-12-14 21:38:09,872 - INFO - [PLTR] Trying fmp fallback...
# 2025-12-14 21:38:10,124 - WARNING - [PLTR] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/PLTR?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 21:38:10,126 - INFO - [PLTR] Trying alpha_vantage for PEG ratio...
# 2025-12-14 21:38:10,373 - INFO - [PLTR] Found PEG ratio from alpha_vantage
# 2025-12-14 21:38:25,376 - INFO - === Completed PLTR. Fields found: 10/10 ===
# 📊 Results (with source attribution):
#   ticker  market_cap_value market_cap_source  trailing_pe_value  \
# 0   IONQ       17837975552          yfinance                NaN
# 1   ASTS       28179679232          yfinance                NaN
# 2   HOOD      107453071360          yfinance          49.791664
# 3   MARA        4356683776          yfinance           4.482490
# 4   PLTR      437527412736          yfinance         417.204560
#
#   trailing_pe_source  peg_ratio_value peg_ratio_source  short_pct_value  \
# 0               None              NaN             None           0.1889
# 1               None              NaN             None           0.1717
# 2           yfinance              NaN             None           0.0537
# 3           yfinance            0.000    alpha_vantage           0.3505
# 4           yfinance            2.882    alpha_vantage           0.0217
#
#   short_pct_source  insider_pct_value insider_pct_source  beta_value  \
# 0         yfinance            0.02630           yfinance       2.617
# 1         yfinance            0.16596           yfinance       2.759
# 2         yfinance            0.00693           yfinance       2.433
# 3         yfinance            0.00570           yfinance       5.442
# 4         yfinance            0.03591           yfinance       1.495
#
#   beta_source
# 0    yfinance
# 1    yfinance
# 2    yfinance
# 3    yfinance
# 4    yfinance
#
# ✅ Multi-source fundamentals scraper tested successfully!
#    Processed: 5 tickers
#    Fields per ticker: 6/6

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import json

class FundamentalDataBatchProcessor:
    """Batch processor with checkpointing for 353 tickers. Runs in 45-60 minutes."""
    
    def __init__(self, tickers, max_workers=5, checkpoint_interval=50):
        self.tickers = tickers
        self.max_workers = max_workers
        self.checkpoint_interval = checkpoint_interval
        self.results = []
        self.failed_tickers = []
        self.progress_file = "data/fundamentals_checkpoint.json"
        self.final_output_file = f"data/results/fundamentals_batch_{datetime.now().strftime('%Y%m%d_%H%M')}.csv"
        
        # Create directories if needed
        os.makedirs('data/results', exist_ok=True)

    def load_checkpoint(self):
        """Load previous progress from checkpoint file."""
        try:
            with open(self.progress_file, 'r') as f:
                saved = json.load(f)
                self.results = saved.get('results', [])
                processed_set = {r['ticker'] for r in self.results}
                # Only process new tickers
                self.tickers = [t for t in self.tickers if t not in processed_set]
                logger.info(f"Loaded checkpoint. {len(self.results)} already processed. {len(self.tickers)} remaining.")
        except FileNotFoundError:
            logger.info("No checkpoint found. Starting fresh.")
        except Exception as e:
            logger.error(f"Error loading checkpoint: {e}. Starting fresh.")

    def save_checkpoint(self):
        """Save current progress to checkpoint file."""
        try:
            checkpoint_data = {
                'timestamp': datetime.utcnow().isoformat(),
                'results': self.results,
                'failed': self.failed_tickers
            }
            with open(self.progress_file, 'w') as f:
                json.dump(checkpoint_data, f, indent=2)
            logger.info(f"Checkpoint saved. {len(self.results)} processed, {len(self.failed_tickers)} failed.")
        except Exception as e:
            logger.error(f"Failed to save checkpoint: {e}")

    def process_single(self, ticker: str):
        """Wrapper with retry logic (exponential backoff)."""
        max_retries = 3
        for attempt in range(max_retries):
            try:
                result = collect_fundamentals_multisource(ticker)
                return result
            except Exception as e:
                if attempt == max_retries - 1:
                    raise e
                wait_time = (2 ** attempt) + 1
                logger.warning(f"[{ticker}] Attempt {attempt+1} failed. Retrying in {wait_time}s.")
                time.sleep(wait_time)

    def run_batch(self):
        """Main batch processor with parallel execution and progress tracking."""
        logger.info(f"Starting batch processing for {len(self.tickers)} tickers with {self.max_workers} workers.")
        self.load_checkpoint()

        if len(self.tickers) == 0:
            logger.info("All tickers already processed!")
            self.save_results_to_csv(0)
            return

        total = len(self.tickers)
        processed = 0
        start_time = time.time()

        with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
            future_to_ticker = {executor.submit(self.process_single, ticker): ticker for ticker in self.tickers}

            for future in as_completed(future_to_ticker):
                ticker = future_to_ticker[future]
                try:
                    result = future.result(timeout=60)
                    self.results.append(result)
                    processed += 1

                    # Progress every 10 tickers
                    if processed % 10 == 0:
                        elapsed = time.time() - start_time
                        eta = (elapsed / processed) * (total - processed) if processed > 0 else 0
                        logger.info(f"Progress: {processed}/{total} ({processed/total:.1%}). ETA: {eta/60:.1f} min.")

                    # Checkpoint every 50 tickers
                    if processed % self.checkpoint_interval == 0:
                        self.save_checkpoint()

                except Exception as e:
                    logger.error(f"Error processing {ticker}: {e}")
                    self.failed_tickers.append({'ticker': ticker, 'error': str(e)})

        elapsed_total = time.time() - start_time
        self.save_results_to_csv(elapsed_total)
        self.save_checkpoint()
        self.print_summary(elapsed_total)

    def save_results_to_csv(self, elapsed_time):
        """Flatten and save results to CSV with source attribution."""
        if not self.results:
            logger.warning("No results to save.")
            return

        flat_rows = []
        for r in self.results:
            flat_row = {'ticker': r['ticker']}
            for field in ['market_cap', 'trailing_pe', 'forward_pe', 'peg_ratio',
                          'short_pct', 'insider_pct', 'institution_pct', 'beta', 'price_to_book', 'price_to_sales']:
                data = r.get(field, {})
                flat_row[f"{field}_value"] = data.get('value')
                flat_row[f"{field}_source"] = data.get('source')
            flat_rows.append(flat_row)

        df = pd.DataFrame(flat_rows)
        
        # Add metadata
        metadata = (
            f"# Generated: {datetime.utcnow().isoformat()}\n"
            f"# Total tickers: {len(self.results) + len(self.failed_tickers)}\n"
            f"# Successfully processed: {len(self.results)}\n"
            f"# Failed: {len(self.failed_tickers)}\n"
            f"# Processing time: {elapsed_time:.1f} seconds ({elapsed_time/60:.1f} minutes)\n"
            f"# Success rate: {len(self.results)/(len(self.results)+len(self.failed_tickers)):.1%}\n"
        )

        with open(self.final_output_file, 'w') as f:
            f.write(metadata)
            df.to_csv(f, index=False)

        logger.info(f"Results saved to {self.final_output_file}")

    def print_summary(self, elapsed_time):
        """Print final summary report."""
        print("\n" + "="*60)
        print("BATCH PROCESSING SUMMARY")
        print("="*60)
        print(f"Total tickers attempted: {len(self.results) + len(self.failed_tickers)}")
        print(f"Successfully processed:  {len(self.results)}")
        print(f"Failed:                  {len(self.failed_tickers)}")
        print(f"Total time:              {elapsed_time/60:.1f} minutes")
        if len(self.results) + len(self.failed_tickers) > 0:
            success_rate = len(self.results)/(len(self.results) + len(self.failed_tickers))
            print(f"Success rate:            {success_rate:.1%}")
        print("="*60)

# ==================== RUN ON ALL 353 TICKERS ====================
# UNCOMMENT BELOW TO RUN FULL BATCH (will take 45-60 minutes)

print("⚠️ Full batch processing: 353 tickers, 45-60 minutes")
print("   Checkpoints saved every 50 tickers for recovery\n")

# Uncomment to run:
# processor = FundamentalDataBatchProcessor(
#     tickers=TICKERS,
#     max_workers=5,
#     checkpoint_interval=50
# )
# processor.run_batch()

# For now, test on 20 tickers to validate:
print("🔄 Testing batch processor on first 20 tickers...")
processor = FundamentalDataBatchProcessor(
    tickers=TICKERS[:20],
    max_workers=3,
    checkpoint_interval=50
)
processor.run_batch()
print("\n✅ Batch processor test complete!")
# Out:
# 2025-12-14 21:38:26,397 - INFO - Starting batch processing for 20 tickers with 3 workers.
# 2025-12-14 21:38:26,410 - INFO - Loaded checkpoint. 20 already processed. 0 remaining.
# 2025-12-14 21:38:26,411 - INFO - All tickers already processed!
# 2025-12-14 21:38:26,415 - INFO - Results saved to data/results/fundamentals_batch_20251214_2138.csv
# ⚠️ Full batch processing: 353 tickers, 45-60 minutes
#    Checkpoints saved every 50 tickers for recovery
#
# 🔄 Testing batch processor on first 20 tickers...
#
# ✅ Batch processor test complete!

# %%
def scrape_google_news(ticker, max_articles=5):
    """
    Scrape Google News RSS feed for ticker
    Free, no API key needed
    """
    url = f"https://news.google.com/rss/search?q={ticker}+stock&hl=en-US&gl=US&ceid=US:en"
    
    try:
        resp = requests.get(url, headers=HEADERS, timeout=10)
        soup = BeautifulSoup(resp.content, features='xml')
        
        news_items = []
        for item in soup.findAll('item')[:max_articles]:
            news_items.append({
                'ticker': ticker,
                'title': item.title.text if item.title else '',
                'published': item.pubDate.text if item.pubDate else '',
                'link': item.link.text if item.link else ''
            })
        
        return news_items
        
    except Exception as e:
        return [{'ticker': ticker, 'error': str(e)}]

# Batch news scraping across many tickers (with rate limiting)
print("🔄 Collecting Google News across the universe (up to 3 per ticker)...")
news_batch = []
max_per_ticker = 3

for i, tk in enumerate(TICKERS[:100], 1):  # start with first 100 to validate
    if i % 20 == 0:
        print(f"  Progress: {i} tickers")
    items = scrape_google_news(tk, max_articles=max_per_ticker)
    news_batch.extend(items)
    time.sleep(0.5)  # polite delay

news_df = pd.DataFrame(news_batch)
valid_news_df = news_df[news_df['title'].fillna('') != ''] if len(news_df) else pd.DataFrame()
print(f"\n✅ Collected {len(valid_news_df)} headlines from {min(100, len(TICKERS))} tickers")
if len(valid_news_df) > 0:
    print("\nSample headlines:")
    for _, row in valid_news_df.head(10).iterrows():
        print(f"  {row['ticker']}: {row['title'][:90]}...")
# Out:
# 🔄 Collecting Google News across the universe (up to 3 per ticker)...
#   Progress: 20 tickers
#   Progress: 40 tickers
#   Progress: 60 tickers
#   Progress: 80 tickers
#   Progress: 100 tickers
#
# ✅ Collected 300 headlines from 100 tickers
#
# Sample headlines:
#   AAPL: Apple Stock (AAPL) Before the US Market Open (Dec. 15, 2025): Key News, Analyst Targets, a...
#   AAPL: Apple Stock Gets Three Price-Target Hikes. Here’s Why. - Investor's Business Daily...
#   AAPL: Apple Inc. Stock (AAPL) Opinions on AI Developments and Leadership Changes - Quiver Quanti...
#   MSFT: MSFT vs. GOOGL vs. NVDA: Which ‘Strong Buy’ Mega-Cap Stock Has the Highest Upside Potentia...
#   MSFT: Microsoft Stock (MSFT) After Hours on Dec. 12, 2025: What Investors Need to Know Before th...
#   MSFT: Better (Almost) $4 Trillion AI Stock to Buy Now: Microsoft or Alphabet - The Motley Fool...
#   NVDA: ‘Dreams Won’t Pay Forever,’ Says Investor About Nvidia Stock - TipRanks...
#   NVDA: The Saturday Spread: Here’s How to Properly Trade the Nvidia (NVDA) Stock Discount - Yahoo...
#   NVDA: Nvidia Stock (NVDA) Before the Market Opens Dec. 15, 2025: Latest News, Key Catalysts, Ana...
#   AMD: Why AMD (AMD) Shares Are Sliding Today - Yahoo Finance...

# %%
# Load FinBERT model for financial sentiment analysis (using safetensors-compatible model)
from transformers import pipeline

print("Loading FinBERT model for GPU sentiment analysis...")
device = 0 if torch.cuda.is_available() else -1

# Use a FinBERT variant that provides safetensors to avoid torch.load vulnerability issues
# Model: yiyanghkust/finbert-tone (widely used, sentiment labels: positive/neutral/negative)
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model="yiyanghkust/finbert-tone",
    device=device,
    truncation=True,
    max_length=512
)

print(f"✅ Model loaded on {'GPU' if device == 0 else 'CPU'}")

# Test GPU speed
test_texts = [
    "Company reports record earnings with 50% revenue growth",
    "Stock plunges on disappointing guidance and regulatory concerns",
    "New product launch expected to drive significant market share gains"
]

start = time.time()
test_results = sentiment_pipeline(test_texts, batch_size=3)
elapsed = time.time() - start

print(f"\n⚡ GPU Speed Test: {len(test_texts)} texts in {elapsed:.3f}s ({len(test_texts)/elapsed:.1f} texts/sec)")
print("\nSample results:")
for text, result in zip(test_texts, test_results):
    print(f"  {result['label']}: {text[:50]}...")
# Out:
# Loading FinBERT model for GPU sentiment analysis...
# config.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/439M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 9
#       5 device = 0 if torch.cuda.is_available() else -1
#       7 # Use a FinBERT variant that provides safetensors to avoid torch.load vulnerability issues
#       8 # Model: yiyanghkust/finbert-tone (widely used, sentiment labels: positive/neutral/negative)
# ----> 9 sentiment_pipeline = pipeline(
#      10     "sentiment-analysis",
#      11     model="yiyanghkust/finbert-tone",
#      12     device=device,
#      13     truncation=True,
#      14     max_length=512
#      15 )
#      17 print(f"✅ Model loaded on {'GPU' if device == 0 else 'CPU'}")
#      19 # Test GPU speed
#
# File ~\Desktop\shadow_ai\Lib\site-packages\transformers\pipelines\__init__.py:1027, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1025 if isinstance(model, str) or framework is None:
#    1026     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# -> 1027     framework, model = infer_framework_load_model(
#    1028         adapter_path if adapter_path is not None else model,
#    1029         model_classes=model_classes,
#    1030         config=config,
#    1031         framework=framework,
#    1032         task=task,
#    1033         **hub_kwargs,
#    1034         **model_kwargs,
#    1035     )
#    1037 hub_kwargs["_commit_hash"] = model.config._commit_hash
#    1039 # Check which preprocessing classes the pipeline uses
#    1040 # None values indicate optional classes that the pipeline can run without, we don't raise errors if loading fails
#
# File ~\Desktop\shadow_ai\Lib\site-packages\transformers\pipelines\base.py:333, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     331         for class_name, trace in all_traceback.items():
#     332             error += f"while loading with {class_name}, an error is thrown:\n{trace}\n"
# --> 333         raise ValueError(
#     334             f"Could not load model {model} with any of the following classes: {class_tuple}. See the original errors:\n\n{error}\n"
#     335         )
#     337 if framework is None:
#     338     framework = infer_framework(model.__class__)
#
# ValueError: Could not load model yiyanghkust/finbert-tone with any of the following classes: (<class 'transformers.models.auto.modeling_auto.AutoModelForSequenceClassification'>, <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'>). See the original errors:
#
# while loading with AutoModelForSequenceClassification, an error is thrown:
# Traceback (most recent call last):
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\pipelines\base.py", line 293, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\models\auto\auto_factory.py", line 604, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 277, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 4962, in from_pretrained
#     config, dtype, dtype_orig = _get_dtype(
#                                 ^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 1250, in _get_dtype
#     state_dict = load_state_dict(
#                  ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 508, in load_state_dict
#     check_torch_load_is_safe()
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\utils\import_utils.py", line 1647, in check_torch_load_is_safe
#     raise ValueError(
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\pipelines\base.py", line 311, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\models\auto\auto_factory.py", line 604, in from_pretrained
#     return model_class.from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 277, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 5048, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 5316, in _load_pretrained_model
#     load_state_dict(checkpoint_files[0], map_location="meta", weights_only=weights_only).keys()
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 508, in load_state_dict
#     check_torch_load_is_safe()
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\utils\import_utils.py", line 1647, in check_torch_load_is_safe
#     raise ValueError(
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# while loading with BertForSequenceClassification, an error is thrown:
# Traceback (most recent call last):
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\pipelines\base.py", line 293, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 277, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 4962, in from_pretrained
#     config, dtype, dtype_orig = _get_dtype(
#                                 ^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 1250, in _get_dtype
#     state_dict = load_state_dict(
#                  ^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 508, in load_state_dict
#     check_torch_load_is_safe()
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\utils\import_utils.py", line 1647, in check_torch_load_is_safe
#     raise ValueError(
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\pipelines\base.py", line 311, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **fp32_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 277, in _wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 5048, in from_pretrained
#     ) = cls._load_pretrained_model(
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 5316, in _load_pretrained_model
#     load_state_dict(checkpoint_files[0], map_location="meta", weights_only=weights_only).keys()
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\modeling_utils.py", line 508, in load_state_dict
#     check_torch_load_is_safe()
#   File "C:\Users\Shadow\Desktop\shadow_ai\Lib\site-packages\transformers\utils\import_utils.py", line 1647, in check_torch_load_is_safe
#     raise ValueError(
# ValueError: Due to a serious vulnerability issue in `torch.load`, even with `weights_only=True`, we now require users to upgrade torch to at least v2.6 in order to use the function. This version restriction does not apply when loading files with safetensors.
# See the vulnerability report here https://nvd.nist.gov/vuln/detail/CVE-2025-32434

# %%
def analyze_sentiment_batch(news_list, batch_size=32):
    """
    GPU-accelerated batch sentiment analysis
    Takes list of news items and returns sentiment scores
    """
    if not news_list or len(news_list) == 0:
        return []
    
    # Extract headlines
    texts = [item.get('title', '') for item in news_list if item.get('title')]
    
    if not texts:
        return []
    
    # Batch process on GPU
    print(f"🔄 Analyzing {len(texts)} headlines on GPU...")
    start = time.time()
    results = sentiment_pipeline(texts, batch_size=batch_size)
    elapsed = time.time() - start
    
    print(f"✅ Processed {len(texts)} texts in {elapsed:.2f}s ({len(texts)/elapsed:.1f} texts/sec)")
    
    # Combine with original data
    for i, item in enumerate(news_list[:len(results)]):
        if 'title' in item:
            sentiment = results[i]
            item['sentiment_label'] = sentiment['label']
            item['sentiment_score'] = sentiment.get('score', 0)
            # Convert to numeric: positive=1, negative=-1, neutral=0
            label = sentiment['label'].lower()
            if 'pos' in label:
                item['sentiment_numeric'] = sentiment.get('score', 0)
            elif 'neg' in label:
                item['sentiment_numeric'] = -sentiment.get('score', 0)
            else:
                item['sentiment_numeric'] = 0
    
    return news_list

# Apply sentiment to the batch news collected
if 'valid_news_df' in globals() and len(valid_news_df) > 0:
    print("\n🚀 Running GPU sentiment analysis on batch news...")
    analyzed_news = analyze_sentiment_batch(valid_news_df.to_dict(orient='records'), batch_size=32)
    sentiment_df = pd.DataFrame(analyzed_news)
    print(f"\n✅ Sentiment annotated: {len(sentiment_df)} headlines")
    print("Sample with sentiment:")
    print(sentiment_df[['ticker', 'sentiment_label', 'sentiment_score', 'title']].head(10))
# Out:
# model.safetensors:   0%|          | 0.00/439M [00:00<?, ?B/s]

# %%
# Load FinBERT model for financial sentiment analysis (FORCE safetensors to avoid CVE)
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

print("Loading FinBERT model with safetensors (avoiding torch.load CVE)...")
device = 0 if torch.cuda.is_available() else -1

# FORCE safetensors loading by loading model separately with use_safetensors=True
model_name = "yiyanghkust/finbert-tone"

print("  Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(model_name)

print("  Loading model with safetensors (bypassing pytorch_model.bin)...")
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    use_safetensors=True,  # FORCE safetensors, skip pytorch_model.bin
    ignore_mismatched_sizes=False
)

# Move to GPU if available
if device == 0:
    model = model.to('cuda')
    print(f"  ✅ Model moved to GPU")

# Create pipeline with pre-loaded model
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device,
    truncation=True,
    max_length=512
)

print(f"\n✅ Model loaded on {'GPU' if device == 0 else 'CPU'}")

# Test GPU speed
test_texts = [
    "Company reports record earnings with 50% revenue growth",
    "Stock plunges on disappointing guidance and regulatory concerns",
    "New product launch expected to drive significant market share gains"
]

start = time.time()
test_results = sentiment_pipeline(test_texts, batch_size=3)
elapsed = time.time() - start

print(f"\n⚡ GPU Speed Test: {len(test_texts)} texts in {elapsed:.3f}s ({len(test_texts)/elapsed:.1f} texts/sec)")
print("\nSample results:")
for text, result in zip(test_texts, test_results):
    print(f"  {result['label']}: {text[:50]}...")
# Out:
# Loading FinBERT model with safetensors (avoiding torch.load CVE)...
#   Loading tokenizer...
# vocab.txt: 0.00B [00:00, ?B/s]
#   Loading model with safetensors (bypassing pytorch_model.bin)...
# Device set to use cuda:0
#   ✅ Model moved to GPU
#
# ✅ Model loaded on GPU
#
# ⚡ GPU Speed Test: 3 texts in 0.162s (18.5 texts/sec)
#
# Sample results:
#   Positive: Company reports record earnings with 50% revenue g...
#   Negative: Stock plunges on disappointing guidance and regula...
#   Positive: New product launch expected to drive significant m...

# %%
def analyze_sentiment_batch(news_list, batch_size=32):
    """
    GPU-accelerated batch sentiment analysis
    Takes list of news items and returns sentiment scores
    """
    if not news_list or len(news_list) == 0:
        return []
    
    # Extract headlines
    texts = [item.get('title', '') for item in news_list if item.get('title')]
    
    if not texts:
        return []
    
    # Batch process on GPU
    print(f"🔄 Analyzing {len(texts)} headlines on GPU...")
    start = time.time()
    results = sentiment_pipeline(texts, batch_size=batch_size)
    elapsed = time.time() - start
    
    print(f"✅ Processed {len(texts)} texts in {elapsed:.2f}s ({len(texts)/elapsed:.1f} texts/sec)")
    
    # Combine with original data
    for i, item in enumerate(news_list[:len(results)]):
        if 'title' in item:
            sentiment = results[i]
            item['sentiment_label'] = sentiment['label']
            item['sentiment_score'] = sentiment.get('score', 0)
            # Convert to numeric: positive=1, negative=-1, neutral=0
            label = sentiment['label'].lower()
            if 'pos' in label:
                item['sentiment_numeric'] = sentiment.get('score', 0)
            elif 'neg' in label:
                item['sentiment_numeric'] = -sentiment.get('score', 0)
            else:
                item['sentiment_numeric'] = 0
    
    return news_list

# Apply sentiment to the batch news collected
if 'valid_news_df' in globals() and len(valid_news_df) > 0:
    print("\n🚀 Running GPU sentiment analysis on batch news...")
    analyzed_news = analyze_sentiment_batch(valid_news_df.to_dict(orient='records'), batch_size=32)
    sentiment_df = pd.DataFrame(analyzed_news)
    print(f"\n✅ Sentiment annotated: {len(sentiment_df)} headlines")
    print("Sample with sentiment:")
    print(sentiment_df[['ticker', 'sentiment_label', 'sentiment_score', 'title']].head(10))
# Out:
# 🚀 Running GPU sentiment analysis on batch news...
# 🔄 Analyzing 300 headlines on GPU...
# ✅ Processed 300 texts in 0.75s (402.0 texts/sec)
#
# ✅ Sentiment annotated: 300 headlines
# Sample with sentiment:
#   ticker sentiment_label  sentiment_score  \
# 0   AAPL         Neutral         0.999952
# 1   AAPL         Neutral         0.999951
# 2   AAPL         Neutral         0.999958
# 3   MSFT        Positive         1.000000
# 4   MSFT         Neutral         0.999946
# 5   MSFT        Positive         0.997819
# 6   NVDA         Neutral         0.999972
# 7   NVDA         Neutral         0.999958
# 8   NVDA         Neutral         0.787294
# 9    AMD        Negative         0.907116
#
#                                                title
# 0  Apple Stock (AAPL) Before the US Market Open (...
# 1  Apple Stock Gets Three Price-Target Hikes. Her...
# 2  Apple Inc. Stock (AAPL) Opinions on AI Develop...
# 3  MSFT vs. GOOGL vs. NVDA: Which ‘Strong Buy’ Me...
# 4  Microsoft Stock (MSFT) After Hours on Dec. 12,...
# 5  Better (Almost) $4 Trillion AI Stock to Buy No...
# 6  ‘Dreams Won’t Pay Forever,’ Says Investor Abou...
# 7  The Saturday Spread: Here’s How to Properly Tr...
# 8  Nvidia Stock (NVDA) Before the Market Opens De...
# 9  Why AMD (AMD) Shares Are Sliding Today - Yahoo...

# %%
def collect_all_data_for_ticker(ticker):
    """
    Master function: Collect ALL data for a single ticker
    Returns: dict with OHLCV, fundamentals, insider, sentiment
    """
    print(f"📊 {ticker}...", end=' ')
    
    data = {'ticker': ticker}
    
    try:
        # 1. OHLCV from yfinance
        ohlcv = yf.download(ticker, period='2y', progress=False)
        if not ohlcv.empty:
            data['bars_count'] = len(ohlcv)
            data['last_price'] = float(ohlcv['Close'].iloc[-1])
            data['avg_volume'] = float(ohlcv['Volume'].mean())
            data['volatility'] = float(ohlcv['Close'].pct_change().std() * np.sqrt(252))
            # Momentum
            data['return_1m'] = float((ohlcv['Close'].iloc[-1] / ohlcv['Close'].iloc[-20] - 1) * 100)
            data['return_3m'] = float((ohlcv['Close'].iloc[-1] / ohlcv['Close'].iloc[-60] - 1) * 100)
        
        time.sleep(0.3)
        
        # 2. Fundamentals from Yahoo scraping
        fundamentals = scrape_yahoo_fundamentals(ticker)
        data.update(fundamentals)
        time.sleep(1)
        
        # 3. Insider trades from SEC
        insider = get_sec_insider_trades(ticker)
        data['insider_trades_count'] = insider.get('insider_trades', 0)
        time.sleep(2)
        
        # 4. News sentiment
        news = scrape_google_news(ticker, max_articles=5)
        if news and len(news) > 0:
            analyzed = analyze_sentiment_batch(news, batch_size=5)
            if analyzed:
                sentiments = [n.get('sentiment_numeric', 0) for n in analyzed if 'sentiment_numeric' in n]
                data['news_count'] = len(analyzed)
                data['avg_sentiment'] = np.mean(sentiments) if sentiments else 0
                data['sentiment_std'] = np.std(sentiments) if len(sentiments) > 1 else 0
        time.sleep(0.5)
        
        print("✓")
        
    except Exception as e:
        print(f"✗ ({str(e)[:30]})")
        data['error'] = str(e)
    
    return data

# TEST on 10 tickers
print("\\n🔬 FULL DATA COLLECTION TEST (10 tickers)\\n")
test_batch = TICKERS[:10]
all_ticker_data = []

for ticker in test_batch:
    ticker_data = collect_all_data_for_ticker(ticker)
    all_ticker_data.append(ticker_data)

# Convert to dataframe
results_df = pd.DataFrame(all_ticker_data)
print(f"\\n✅ Collected data for {len(results_df)} tickers")
print("\\nSample results:")
print(results_df[['ticker', 'last_price', 'return_1m', 'avg_sentiment', 'insider_trades_count']].head())
# Out:
# \n🔬 FULL DATA COLLECTION TEST (10 tickers)\n
# 📊 AAPL... ✗ (name 'scrape_yahoo_fundamental)
# 📊 MSFT... ✗ (name 'scrape_yahoo_fundamental)
# 📊 NVDA... ✗ (name 'scrape_yahoo_fundamental)
# 📊 AMD... ✗ (name 'scrape_yahoo_fundamental)
# 📊 AVGO... ✗ (name 'scrape_yahoo_fundamental)
# 📊 MSTR... ✗ (name 'scrape_yahoo_fundamental)
# 📊 IONQ... ✗ (name 'scrape_yahoo_fundamental)
# 📊 GOOGL... ✗ (name 'scrape_yahoo_fundamental)
# 📊 META... ✗ (name 'scrape_yahoo_fundamental)
# 📊 TSLA... ✗ (name 'scrape_yahoo_fundamental)
# \n✅ Collected data for 10 tickers
# \nSample results:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 66
#      64 print(f"\\n✅ Collected data for {len(results_df)} tickers")
#      65 print("\\nSample results:")
# ---> 66 print(results_df[['ticker', 'last_price', 'return_1m', 'avg_sentiment', 'insider_trades_count']].head())
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['avg_sentiment', 'insider_trades_count'] not in index"

# %%
# Load FinBERT model for financial sentiment analysis (FORCE safetensors to avoid CVE)
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

print("Loading FinBERT model with safetensors (avoiding torch.load CVE)...")
device = 0 if torch.cuda.is_available() else -1

# FORCE safetensors loading by loading model separately with use_safetensors=True
model_name = "yiyanghkust/finbert-tone"

print("  Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(model_name)

print("  Loading model with safetensors (bypassing pytorch_model.bin)...")
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    use_safetensors=True,  # FORCE safetensors, skip pytorch_model.bin
    ignore_mismatched_sizes=False
)

# Move to GPU if available
if device == 0:
    model = model.to('cuda')
    print(f"  ✅ Model moved to GPU")

# Create pipeline with pre-loaded model
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device,
    truncation=True,
    max_length=512
)

print(f"\n✅ Model loaded on {'GPU' if device == 0 else 'CPU'}")

# Test GPU speed
test_texts = [
    "Company reports record earnings with 50% revenue growth",
    "Stock plunges on disappointing guidance and regulatory concerns",
    "New product launch expected to drive significant market share gains"
]

start = time.time()
test_results = sentiment_pipeline(test_texts, batch_size=3)
elapsed = time.time() - start

print(f"\n⚡ GPU Speed Test: {len(test_texts)} texts in {elapsed:.3f}s ({len(test_texts)/elapsed:.1f} texts/sec)")
print("\nSample results:")
for text, result in zip(test_texts, test_results):
    print(f"  {result['label']}: {text[:50]}...")
# Out:
# Loading FinBERT model with safetensors (avoiding torch.load CVE)...
#   Loading tokenizer...
#   Loading model with safetensors (bypassing pytorch_model.bin)...
# Device set to use cuda:0
#   ✅ Model moved to GPU
#
# ✅ Model loaded on GPU
#
# ⚡ GPU Speed Test: 3 texts in 0.035s (87.0 texts/sec)
#
# Sample results:
#   Positive: Company reports record earnings with 50% revenue g...
#   Negative: Stock plunges on disappointing guidance and regula...
#   Positive: New product launch expected to drive significant m...

# %%
# Load FinBERT model for financial sentiment analysis (FORCE safetensors to avoid CVE)
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

print("Loading FinBERT model with safetensors (avoiding torch.load CVE)...")
device = 0 if torch.cuda.is_available() else -1

# FORCE safetensors loading by loading model separately with use_safetensors=True
model_name = "yiyanghkust/finbert-tone"

print("  Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(model_name)

print("  Loading model with safetensors (bypassing pytorch_model.bin)...")
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    use_safetensors=True,  # FORCE safetensors, skip pytorch_model.bin
    ignore_mismatched_sizes=False
)

# Move to GPU if available
if device == 0:
    model = model.to('cuda')
    print(f"  ✅ Model moved to GPU")

# Create pipeline with pre-loaded model
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device,
    truncation=True,
    max_length=512
)

print(f"\n✅ Model loaded on {'GPU' if device == 0 else 'CPU'}")

# Test GPU speed
test_texts = [
    "Company reports record earnings with 50% revenue growth",
    "Stock plunges on disappointing guidance and regulatory concerns",
    "New product launch expected to drive significant market share gains"
]

start = time.time()
test_results = sentiment_pipeline(test_texts, batch_size=3)
elapsed = time.time() - start

print(f"\n⚡ GPU Speed Test: {len(test_texts)} texts in {elapsed:.3f}s ({len(test_texts)/elapsed:.1f} texts/sec)")
print("\nSample results:")
for text, result in zip(test_texts, test_results):
    print(f"  {result['label']}: {text[:50]}...")
# Out:
# Loading FinBERT model with safetensors (avoiding torch.load CVE)...
#   Loading tokenizer...
#   Loading model with safetensors (bypassing pytorch_model.bin)...
# Device set to use cuda:0
#   ✅ Model moved to GPU
#
# ✅ Model loaded on GPU
#
# ⚡ GPU Speed Test: 3 texts in 0.090s (33.3 texts/sec)
#
# Sample results:
#   Positive: Company reports record earnings with 50% revenue g...
#   Negative: Stock plunges on disappointing guidance and regula...
#   Positive: New product launch expected to drive significant m...

# %%
def analyze_sentiment_batch(news_list, batch_size=32):
    """
    GPU-accelerated batch sentiment analysis
    Takes list of news items and returns sentiment scores
    """
    if not news_list or len(news_list) == 0:
        return []
    
    # Extract headlines
    texts = [item.get('title', '') for item in news_list if item.get('title')]
    
    if not texts:
        return []
    
    # Batch process on GPU
    print(f"🔄 Analyzing {len(texts)} headlines on GPU...")
    start = time.time()
    results = sentiment_pipeline(texts, batch_size=batch_size)
    elapsed = time.time() - start
    
    print(f"✅ Processed {len(texts)} texts in {elapsed:.2f}s ({len(texts)/elapsed:.1f} texts/sec)")
    
    # Combine with original data
    for i, item in enumerate(news_list[:len(results)]):
        if 'title' in item:
            sentiment = results[i]
            item['sentiment_label'] = sentiment['label']
            item['sentiment_score'] = sentiment.get('score', 0)
            # Convert to numeric: positive=1, negative=-1, neutral=0
            label = sentiment['label'].lower()
            if 'pos' in label:
                item['sentiment_numeric'] = sentiment.get('score', 0)
            elif 'neg' in label:
                item['sentiment_numeric'] = -sentiment.get('score', 0)
            else:
                item['sentiment_numeric'] = 0
    
    return news_list

# Apply sentiment to the batch news collected
if 'valid_news_df' in globals() and len(valid_news_df) > 0:
    print("\n🚀 Running GPU sentiment analysis on batch news...")
    analyzed_news = analyze_sentiment_batch(valid_news_df.to_dict(orient='records'), batch_size=32)
    sentiment_df = pd.DataFrame(analyzed_news)
    print(f"\n✅ Sentiment annotated: {len(sentiment_df)} headlines")
    print("Sample with sentiment:")
    print(sentiment_df[['ticker', 'sentiment_label', 'sentiment_score', 'title']].head(10))
# Out:
# 🚀 Running GPU sentiment analysis on batch news...
# 🔄 Analyzing 300 headlines on GPU...
# ✅ Processed 300 texts in 0.81s (370.7 texts/sec)
#
# ✅ Sentiment annotated: 300 headlines
# Sample with sentiment:
#   ticker sentiment_label  sentiment_score  \
# 0   AAPL         Neutral         0.999952
# 1   AAPL         Neutral         0.999951
# 2   AAPL         Neutral         0.999958
# 3   MSFT        Positive         1.000000
# 4   MSFT         Neutral         0.999946
# 5   MSFT        Positive         0.997819
# 6   NVDA         Neutral         0.999972
# 7   NVDA         Neutral         0.999958
# 8   NVDA         Neutral         0.787294
# 9    AMD        Negative         0.907116
#
#                                                title
# 0  Apple Stock (AAPL) Before the US Market Open (...
# 1  Apple Stock Gets Three Price-Target Hikes. Her...
# 2  Apple Inc. Stock (AAPL) Opinions on AI Develop...
# 3  MSFT vs. GOOGL vs. NVDA: Which ‘Strong Buy’ Me...
# 4  Microsoft Stock (MSFT) After Hours on Dec. 12,...
# 5  Better (Almost) $4 Trillion AI Stock to Buy No...
# 6  ‘Dreams Won’t Pay Forever,’ Says Investor Abou...
# 7  The Saturday Spread: Here’s How to Properly Tr...
# 8  Nvidia Stock (NVDA) Before the Market Opens De...
# 9  Why AMD (AMD) Shares Are Sliding Today - Yahoo...

# %%
def collect_all_data_for_ticker(ticker):
    """
    Master function: Collect ALL data for a single ticker
    Returns: dict with OHLCV, fundamentals, insider, sentiment
    """
    print(f"📊 {ticker}...", end=' ')
    
    data = {'ticker': ticker}
    
    try:
        # 1. OHLCV from yfinance
        ohlcv = yf.download(ticker, period='2y', progress=False)
        if not ohlcv.empty:
            data['bars_count'] = len(ohlcv)
            data['last_price'] = float(ohlcv['Close'].iloc[-1])
            data['avg_volume'] = float(ohlcv['Volume'].mean())
            data['volatility'] = float(ohlcv['Close'].pct_change().std() * np.sqrt(252))
            # Momentum
            data['return_1m'] = float((ohlcv['Close'].iloc[-1] / ohlcv['Close'].iloc[-20] - 1) * 100)
            data['return_3m'] = float((ohlcv['Close'].iloc[-1] / ohlcv['Close'].iloc[-60] - 1) * 100)
        
        time.sleep(0.3)
        
        # 2. Fundamentals from multi-source collector
        fundamentals = collect_fundamentals_multisource(ticker)
        # Extract just the values, not the source attribution
        for field, field_data in fundamentals.items():
            if field != 'ticker' and isinstance(field_data, dict):
                data[field] = field_data.get('value')
        time.sleep(1)
        
        # 3. Insider trades from SEC
        insider = get_sec_insider_trades(ticker)
        data['insider_trades_count'] = insider.get('insider_trades', 0)
        time.sleep(2)
        
        # 4. News sentiment
        news = scrape_google_news(ticker, max_articles=5)
        if news and len(news) > 0:
            analyzed = analyze_sentiment_batch(news, batch_size=5)
            if analyzed:
                sentiments = [n.get('sentiment_numeric', 0) for n in analyzed if 'sentiment_numeric' in n]
                data['news_count'] = len(analyzed)
                data['avg_sentiment'] = np.mean(sentiments) if sentiments else 0
                data['sentiment_std'] = np.std(sentiments) if len(sentiments) > 1 else 0
        time.sleep(0.5)
        
        print("✓")
        
    except Exception as e:
        print(f"✗ ({str(e)[:30]})")
        data['error'] = str(e)
    
    return data

# TEST on 10 tickers
print("\\n🔬 FULL DATA COLLECTION TEST (10 tickers)\\n")
test_batch = TICKERS[:10]
all_ticker_data = []

for ticker in test_batch:
    ticker_data = collect_all_data_for_ticker(ticker)
    all_ticker_data.append(ticker_data)

# Convert to dataframe
results_df = pd.DataFrame(all_ticker_data)
print(f"\\n✅ Collected data for {len(results_df)} tickers")
print(f"\\nColumns collected: {list(results_df.columns)}")
print("\\nSample results (all available columns):")
# Show only columns that exist
available_cols = ['ticker', 'last_price', 'return_1m']
available_cols.extend([c for c in ['avg_sentiment', 'insider_trades_count', 'market_cap', 'trailing_pe'] if c in results_df.columns])
print(results_df[available_cols].head())
# Out:
# \n🔬 FULL DATA COLLECTION TEST (10 tickers)\n
# 📊 AAPL...
# 2025-12-14 22:03:55,619 - INFO - === Starting collection for AAPL ===
# 2025-12-14 22:03:55,852 - INFO - [AAPL] Retrieved 9 fields from yfinance
# 2025-12-14 22:03:55,852 - INFO - [AAPL] Trying fmp fallback...
# 2025-12-14 22:03:56,115 - WARNING - [AAPL] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/AAPL?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:03:56,117 - INFO - [AAPL] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:03:56,350 - INFO - [AAPL] Found PEG ratio from alpha_vantage
# 2025-12-14 22:04:11,352 - INFO - === Completed AAPL. Fields found: 10/10 ===
# ✗ (name 'get_sec_insider_trades' )
# 📊 MSFT...
# 2025-12-14 22:04:12,767 - INFO - === Starting collection for MSFT ===
# 2025-12-14 22:04:13,043 - INFO - [MSFT] Retrieved 9 fields from yfinance
# 2025-12-14 22:04:13,043 - INFO - [MSFT] Trying fmp fallback...
# 2025-12-14 22:04:13,262 - WARNING - [MSFT] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/MSFT?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:04:13,263 - INFO - [MSFT] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:04:13,505 - INFO - [MSFT] Found PEG ratio from alpha_vantage
# 2025-12-14 22:04:28,507 - INFO - === Completed MSFT. Fields found: 10/10 ===
# ✗ (name 'get_sec_insider_trades' )
# 📊 NVDA...
# 2025-12-14 22:04:29,900 - INFO - === Starting collection for NVDA ===
# 2025-12-14 22:04:30,109 - INFO - [NVDA] Retrieved 9 fields from yfinance
# 2025-12-14 22:04:30,110 - INFO - [NVDA] Trying fmp fallback...
# 2025-12-14 22:04:30,331 - WARNING - [NVDA] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/NVDA?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:04:30,333 - INFO - [NVDA] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:04:30,609 - INFO - [NVDA] Found PEG ratio from alpha_vantage
# 2025-12-14 22:04:45,612 - INFO - === Completed NVDA. Fields found: 10/10 ===
# ✗ (name 'get_sec_insider_trades' )
# 📊 AMD...
# 2025-12-14 22:04:47,057 - INFO - === Starting collection for AMD ===
# 2025-12-14 22:04:47,325 - INFO - [AMD] Retrieved 9 fields from yfinance
# 2025-12-14 22:04:47,326 - INFO - [AMD] Trying fmp fallback...
# 2025-12-14 22:04:47,626 - WARNING - [AMD] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/AMD?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:04:47,628 - INFO - [AMD] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:04:47,869 - INFO - [AMD] Found PEG ratio from alpha_vantage
# 2025-12-14 22:05:02,871 - INFO - === Completed AMD. Fields found: 10/10 ===
# ✗ (name 'get_sec_insider_trades' )
# 📊 AVGO...
# 2025-12-14 22:05:04,286 - INFO - === Starting collection for AVGO ===
# 2025-12-14 22:05:04,512 - INFO - [AVGO] Retrieved 9 fields from yfinance
# 2025-12-14 22:05:04,513 - INFO - [AVGO] Trying fmp fallback...
# 2025-12-14 22:05:04,756 - WARNING - [AVGO] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/AVGO?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:05:04,758 - INFO - [AVGO] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:05:05,006 - INFO - [AVGO] Found PEG ratio from alpha_vantage
# 2025-12-14 22:05:20,009 - INFO - === Completed AVGO. Fields found: 10/10 ===
# ✗ (name 'get_sec_insider_trades' )
# 📊 MSTR...
# 2025-12-14 22:05:21,411 - INFO - === Starting collection for MSTR ===
# 2025-12-14 22:05:21,626 - INFO - [MSTR] Retrieved 9 fields from yfinance
# 2025-12-14 22:05:21,627 - INFO - [MSTR] Trying fmp fallback...
# 2025-12-14 22:05:21,896 - WARNING - [MSTR] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/MSTR?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:05:21,898 - INFO - [MSTR] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:05:22,213 - INFO - [MSTR] Found PEG ratio from alpha_vantage
# 2025-12-14 22:05:37,218 - INFO - === Completed MSTR. Fields found: 10/10 ===
# ✗ (name 'get_sec_insider_trades' )
# 📊 IONQ...
# 2025-12-14 22:05:38,610 - INFO - === Starting collection for IONQ ===
# 2025-12-14 22:05:38,874 - INFO - [IONQ] Retrieved 8 fields from yfinance
# 2025-12-14 22:05:38,874 - INFO - [IONQ] Trying fmp fallback...
# 2025-12-14 22:05:39,116 - WARNING - [IONQ] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/IONQ?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:05:39,117 - INFO - [IONQ] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:05:54,361 - INFO - === Completed IONQ. Fields found: 8/10 ===
# ✗ (name 'get_sec_insider_trades' )
# 📊 GOOGL...
# 2025-12-14 22:05:55,754 - INFO - === Starting collection for GOOGL ===
# 2025-12-14 22:05:56,066 - INFO - [GOOGL] Retrieved 9 fields from yfinance
# 2025-12-14 22:05:56,067 - INFO - [GOOGL] Trying fmp fallback...
# 2025-12-14 22:05:56,293 - WARNING - [GOOGL] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/GOOGL?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:05:56,294 - INFO - [GOOGL] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:05:56,526 - INFO - [GOOGL] Found PEG ratio from alpha_vantage
# 2025-12-14 22:06:11,529 - INFO - === Completed GOOGL. Fields found: 10/10 ===
# ✗ (name 'get_sec_insider_trades' )
# 📊 META...
# 2025-12-14 22:06:12,922 - INFO - === Starting collection for META ===
# 2025-12-14 22:06:13,154 - INFO - [META] Retrieved 9 fields from yfinance
# 2025-12-14 22:06:13,155 - INFO - [META] Trying fmp fallback...
# 2025-12-14 22:06:13,366 - WARNING - [META] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/META?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:06:13,368 - INFO - [META] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:06:13,630 - INFO - [META] Found PEG ratio from alpha_vantage
# 2025-12-14 22:06:28,632 - INFO - === Completed META. Fields found: 10/10 ===
# ✗ (name 'get_sec_insider_trades' )
# 📊 TSLA...
# 2025-12-14 22:06:30,003 - INFO - === Starting collection for TSLA ===
# 2025-12-14 22:06:30,235 - INFO - [TSLA] Retrieved 9 fields from yfinance
# 2025-12-14 22:06:30,235 - INFO - [TSLA] Trying fmp fallback...
# 2025-12-14 22:06:30,730 - WARNING - [TSLA] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/TSLA?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:06:30,731 - INFO - [TSLA] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:06:30,973 - INFO - [TSLA] Found PEG ratio from alpha_vantage
# 2025-12-14 22:06:45,976 - INFO - === Completed TSLA. Fields found: 10/10 ===
# ✗ (name 'get_sec_insider_trades' )
# \n✅ Collected data for 10 tickers
# \nColumns collected: ['ticker', 'bars_count', 'last_price', 'avg_volume', 'volatility', 'return_1m', 'return_3m', 'market_cap', 'trailing_pe', 'forward_pe', 'peg_ratio', 'short_pct', 'insider_pct', 'institution_pct', 'beta', 'price_to_book', 'price_to_sales', 'error']
# \nSample results (all available columns):
#   ticker  last_price  return_1m     market_cap  trailing_pe
# 0   AAPL  278.279999   2.154838  4129783545856    37.302948
# 1   MSFT  478.529999  -6.028138  3556993138688    34.010662
# 2   NVDA  175.020004  -7.961428  4261212061696    43.321785
# 3    AMD  210.779999 -14.598274   343158620160   109.781250
# 4   AVGO  359.929993   5.101326  1699720724480    75.141960

# %%
def calculate_composite_score(df):
    """
    Calculate multi-factor score for ranking stocks
    
    Factors:
    1. Momentum (30%): 1-month and 3-month returns
    2. Sentiment (20%): News sentiment score
    3. Insider Activity (15%): Recent Form 4 fildef calculate_composite_score(df):
    """
    Calculate multi-factor score for ranking stocks
    
    Factors:
    1. Momentum (30%): 1-month and 3-month returns
    2. Sentiment (20%): News sentiment score
    3. Insider Activity (15%): Recent Form 4 filings
    4. Volatility (15%): Higher vol = more opportunity
    5. Value (10%): P/E ratio (lower better)
    6. Short Interest (10%): High short % = squeeze potential
    """
    
    scores = pd.DataFrame(index=df.index)
    
    # 1. Momentum Score (30%)
    df['return_1m_clean'] = pd.to_numeric(df['return_1m'], errors='coerce')
    df['return_3m_clean'] = pd.to_numeric(df['return_3m'], errors='coerce')
    
    scores['momentum'] = (
        df['return_1m_clean'].fillna(0) * 0.6 + 
        df['return_3m_clean'].fillna(0) * 0.4
    )
    
    # 2. Sentiment Score (20%)
    scores['sentiment'] = df['avg_sentiment'].fillna(0) * 100
    
    # 3. Insider Activity Score (15%)
    scores['insider'] = df['insider_trades_count'].fillna(0) * 10
    
    # 4. Volatility Score (15%) - normalized
    df['volatility_clean'] = pd.to_numeric(df['volatility'], errors='coerce')
    scores['volatility'] = df['volatility_clean'].fillna(0) * 100
    
    # 5. Value Score (10%) - inverse P/E
    df['pe_clean'] = df['trailing_pe'].replace('N/A', np.nan)
    df['pe_clean'] = pd.to_numeric(df['pe_clean'], errors='coerce')
    scores['value'] = 100 / (df['pe_clean'].fillna(50) + 1)  # Lower P/E = higher score
    
    # 6. Short Interest Score (10%)
    df['short_clean'] = df['short_pct'].replace('N/A', np.nan)
    df['short_clean'] = pd.to_numeric(df['short_clean'].str.rstrip('%'), errors='coerce')
    scores['short_squeeze'] = df['short_clean'].fillna(0) * 2
    
    # Normalize all scores to 0-100
    for col in scores.columns:
        min_val = scores[col].min()
        max_val = scores[col].max()
        if max_val > min_val:
            scores[col] = (scores[col] - min_val) / (max_val - min_val) * 100
    
    # Composite score with weights
    weights = {
        'momentum': 0.30,
        'sentiment': 0.20,
        'insider': 0.15,
        'volatility': 0.15,
        'value': 0.10,
        'short_squeeze': 0.10
    }
    
    df['composite_score'] = sum(scores[factor] * weight for factor, weight in weights.items())
    
    # Add individual factor scores
    for factor in scores.columns:
        df[f'{factor}_score'] = scores[factor]
    
    return df

# Apply scoring to test data
if len(results_df) > 0:
    print("🎯 Calculating composite scores...")
    scored_df = calculate_composite_score(results_df.copy())
    
    # Rank by score
    scored_df = scored_df.sort_values('composite_score', ascending=False)
    
    print("\n🏆 TOP RANKED TICKERS:")
    print(scored_df[['ticker', 'composite_score', 'momentum_score', 
                     'sentiment_score', 'insider_score', 'last_price']].head(10))ings
    4. Volatility (15%): Higher vol = more opportunity
    5. Value (10%): P/E ratio (lower better)
    6. Short Interest (10%): High short % = squeeze potential
    """
    
    scores = pd.DataFrame(index=df.index)
    
    # 1. Momentum Score (30%)
    df['return_1m_clean'] = pd.to_numeric(df['return_1m'], errors='coerce')
    df['return_3m_clean'] = pd.to_numeric(df['return_3m'], errors='coerce')
    
    scores['momentum'] = (
        df['return_1m_clean'].fillna(0) * 0.6 + 
        df['return_3m_clean'].fillna(0) * 0.4
    )
    
    # 2. Sentiment Score (20%)
    scores['sentiment'] = df['avg_sentiment'].fillna(0) * 100
    
    # 3. Insider Activity Score (15%)
    scores['insider'] = df['insider_trades_count'].fillna(0) * 10
    
    # 4. Volatility Score (15%) - normalized
    df['volatility_clean'] = pd.to_numeric(df['volatility'], errors='coerce')
    scores['volatility'] = df['volatility_clean'].fillna(0) * 100
    
    # 5. Value Score (10%) - inverse P/E
    df['pe_clean'] = df['trailing_pe'].replace('N/A', np.nan)
    df['pe_clean'] = pd.to_numeric(df['pe_clean'], errors='coerce')
    scores['value'] = 100 / (df['pe_clean'].fillna(50) + 1)  # Lower P/E = higher score
    
    # 6. Short Interest Score (10%)
    df['short_clean'] = df['short_pct'].replace('N/A', np.nan)
    df['short_clean'] = pd.to_numeric(df['short_clean'].str.rstrip('%'), errors='coerce')
    scores['short_squeeze'] = df['short_clean'].fillna(0) * 2
    
    # Normalize all scores to 0-100
    for col in scores.columns:
        min_val = scores[col].min()
        max_val = scores[col].max()
        if max_val > min_val:
            scores[col] = (scores[col] - min_val) / (max_val - min_val) * 100
    
    # Composite score with weights
    weights = {
        'momentum': 0.30,
        'sentiment': 0.20,
        'insider': 0.15,
        'volatility': 0.15,
        'value': 0.10,
        'short_squeeze': 0.10
    }
    
    df['composite_score'] = sum(scores[factor] * weight for factor, weight in weights.items())
    
    # Add individual factor scores
    for factor in scores.columns:
        df[f'{factor}_score'] = scores[factor]
    
    return df

# Apply scoring to test data
if len(results_df) > 0:
    print("🎯 Calculating composite scores...")
    scored_df = calculate_composite_score(results_df.copy())
    
    # Rank by score
    scored_df = scored_df.sort_values('composite_score', ascending=False)
    
    print("\n🏆 TOP RANKED TICKERS:")
    print(scored_df[['ticker', 'composite_score', 'momentum_score', 
                     'sentiment_score', 'insider_score', 'last_price']].head(10))
# Out:
#   Cell In[25], line 10
#     Calculate multi-factor score for ranking stocks
#               ^
# SyntaxError: invalid syntax

# %%
# WARNING: This will take 2-3 hours for 353 tickers
# Uncomment to run full pipeline

# print("=" * 60)
# print("🚀 RUNNING FULL PIPELINE ON 353 TICKERS")
# print("=" * 60)# WARNING: This will take 2-3 hours for 353 tickers
# Uncomment to run full pipeline

# print("=" * 60)
# print("🚀 RUNNING FULL PIPELINE ON 353 TICKERS")
# print("=" * 60)
# print(f"Started: {datetime.now()}")
# print(f"Estimated time: 2-3 hours\\n")

# all_results = []
# failed_tickers = []

# for i, ticker in enumerate(TICKERS, 1):
#     print(f"[{i}/{len(TICKERS)}] ", end='')
#     try:
#         data = collect_all_data_for_ticker(ticker)
#         all_results.append(data)
#     except Exception as e:
#         print(f"{ticker} FAILED: {e}")
#         failed_tickers.append(ticker)
    
#     # Save checkpoint every 50 tickers
#     if i % 50 == 0:
#         checkpoint_df = pd.DataFrame(all_results)
#         checkpoint_df.to_csv(f'{DATA_DIR}/checkpoint_{i}.csv', index=False)
#         print(f"\\n📁 Checkpoint saved: {i} tickers\\n")

# # Final save
# final_df = pd.DataFrame(all_results)
# final_df.to_csv(f'{DATA_DIR}/all_353_tickers_raw.csv', index=False)

# print(f"\\n✅ COMPLETE at {datetime.now()}")
# print(f"Success: {len(all_results)}, Failed: {len(failed_tickers)}")

print("⚠️ FULL PIPELINE READY - Uncomment above code to run")
print("💡 Recommended: Start with 30-50 tickers first to validate")
# print(f"Started: {datetime.now()}")
# print(f"Estimated time: 2-3 hours\\n")

# all_results = []
# failed_tickers = []

# for i, ticker in enumerate(TICKERS, 1):
#     print(f"[{i}/{len(TICKERS)}] ", end='')
#     try:
#         data = collect_all_data_for_ticker(ticker)
#         all_results.append(data)
#     except Exception as e:
#         print(f"{ticker} FAILED: {e}")
#         failed_tickers.append(ticker)
    
#     # Save checkpoint every 50 tickers
#     if i % 50 == 0:
#         checkpoint_df = pd.DataFrame(all_results)
#         checkpoint_df.to_csv(f'{DATA_DIR}/checkpoint_{i}.csv', index=False)
#         print(f"\\n📁 Checkpoint saved: {i} tickers\\n")

# # Final save
# final_df = pd.DataFrame(all_results)
# final_df.to_csv(f'{DATA_DIR}/all_353_tickers_raw.csv', index=False)

# print(f"\\n✅ COMPLETE at {datetime.now()}")
# print(f"Success: {len(all_results)}, Failed: {len(failed_tickers)}")

print("⚠️ FULL PIPELINE READY - Uncomment above code to run")
print("💡 Recommended: Start with 30-50 tickers first to validate")

# %%
# After running full pipeline, use this to extract top 50

# # Load raw data
# full_df = pd.read_csv(f'{DATA_DIR}/all_353_tickers_raw.csv')

# # Calculate scores
# scored_df = calculate_composite_score(full_df)

# # Rank and select top 50
# top50 = scored_df.nlargest(50, 'composite_score')

# # Save results
# top50.to_csv(OUTPUT_FILE, index=False)

# print("🏆 TOP 50 TICKERS SELECTED")
# print("\nBreakdown by sector:")
# print(top50['sector'].value_counts())
# print("\nTop 10:")
# print(top50[['ticker', 'composite_score', 'sector', 'last_price', 
#              'return_1m', 'avg_sentiment']].head(10))

# # Create watchlist file
# with open(f'{DATA_DIR}/top50_watchlist.txt', 'w') as f:
#     for ticker in top50['ticker']:
#         f.write(f"{ticker}\\n")

# print(f"\n✅ Saved to: {OUTPUT_FILE}")
# print(f"✅ Watchlist: {DATA_DIR}/top50_watchlist.txt")

print("⚠️ Run after full pipeline completes")

# %%
def get_sec_insider_trades(ticker):
    """
    Get insider trading data from SEC EDGAR using their JSON API
    100% free, no API key needed
    """
    try:
        # Step 1: Get CIK (company ID) from ticker
        cik_lookup_url = "https://www.sec.gov/files/company_tickers.json"
        cik_data = requests.get(cik_lookup_url, headers=HEADERS, timeout=10).json()
        
        cik = None
        for entry in cik_data.values():
            if entry['ticker'].upper() == ticker.upper():
                cik = str(entry['cik_str']).zfill(10)  # Pad with zeros
                break
        
        if not cik:
            return {'ticker': ticker, 'insider_trades': 0, 'recent_filings': []}
        
        # Step 2: Get filing history from SEC
        filing_url = f"https://data.sec.gov/submissions/CIK{cik}.json"
        filing_data = requests.get(filing_url, headers=HEADERS, timeout=10).json()
        
        # Step 3: Filter for Form 4 (insider trades) and 8-K (major events)
        filings_df = pd.DataFrame(filing_data['filings']['recent'])
        insider_filings = filings_df[filings_df['form'].isin(['4', '8-K'])].head(10)
        
        recent_trades = []
        for _, filing in insider_filings.iterrows():
            recent_trades.append({
                'date': filing['filingDate'],
                'form': filing['form'],
                'description': filing.get('primaryDocDescription', 'N/A')
            })
        
        return {
            'ticker': ticker,
            'cik': cik,
            'insider_trades': len(insider_filings[insider_filings['form'] == '4']),
            'recent_filings': recent_trades
        }
        
    except Exception as e:
        return {'ticker': ticker, 'error': str(e), 'insider_trades': 0}

# Test on 3 tickers
print("🔄 Testing SEC insider scraper...")
test_insiders = []
for ticker in ['NVDA', 'IONQ', 'HOOD']:
    print(f"  Fetching {ticker} SEC filings...")
    insider = get_sec_insider_trades(ticker)
    test_insiders.append(insider)
    time.sleep(2)  # SEC rate limit

for ins in test_insiders:
    print(f"\n{ins['ticker']}: {ins.get('insider_trades', 0)} recent Form 4 filings")
    if 'recent_filings' in ins:
        for filing in ins['recent_filings'][:3]:
            print(f"  - {filing['date']} [{filing['form']}]")
# Out:
# 🔄 Testing SEC insider scraper...
#   Fetching NVDA SEC filings...
#   Fetching IONQ SEC filings...
#   Fetching HOOD SEC filings...
#
# NVDA: 10 recent Form 4 filings
#   - 2025-12-12 [4]
#   - 2025-12-12 [4]
#   - 2025-12-12 [4]
#
# IONQ: 6 recent Form 4 filings
#   - 2025-12-12 [4]
#   - 2025-12-12 [4]
#   - 2025-11-21 [4]
#
# HOOD: 10 recent Form 4 filings
#   - 2025-12-12 [4]
#   - 2025-12-09 [4]
#   - 2025-12-05 [4]

# %%
def scrape_google_news(ticker, max_articles=5):
    """
    Scrape Google News RSS feed for ticker
    Free, no API key needed
    """
    url = f"https://news.google.com/rss/search?q={ticker}+stock&hl=en-US&gl=US&ceid=US:en"
    
    try:
        resp = requests.get(url, headers=HEADERS, timeout=10)
        soup = BeautifulSoup(resp.content, features='xml')
        
        news_items = []
        for item in soup.findAll('item')[:max_articles]:
            news_items.append({
                'ticker': ticker,
                'title': item.title.text if item.title else '',
                'published': item.pubDate.text if item.pubDate else '',
                'link': item.link.text if item.link else ''
            })
        
        return news_items
        
    except Exception as e:
        return [{'ticker': ticker, 'error': str(e)}]

# Batch news scraping across many tickers (with rate limiting)
print("🔄 Collecting Google News across the universe (up to 3 per ticker)...")
news_batch = []
max_per_ticker = 3

for i, tk in enumerate(TICKERS[:100], 1):  # start with first 100 to validate
    if i % 20 == 0:
        print(f"  Progress: {i} tickers")
    items = scrape_google_news(tk, max_articles=max_per_ticker)
    news_batch.extend(items)
    time.sleep(0.5)  # polite delay

news_df = pd.DataFrame(news_batch)
valid_news_df = news_df[news_df['title'].fillna('') != ''] if len(news_df) else pd.DataFrame()
print(f"\n✅ Collected {len(valid_news_df)} headlines from {min(100, len(TICKERS))} tickers")
if len(valid_news_df) > 0:
    print("\nSample headlines:")
    for _, row in valid_news_df.head(10).iterrows():
        print(f"  {row['ticker']}: {row['title'][:90]}...")
# Out:
# 🔄 Collecting Google News across the universe (up to 3 per ticker)...
#   Progress: 20 tickers
#   Progress: 40 tickers
#   Progress: 60 tickers
#   Progress: 80 tickers
#   Progress: 100 tickers
#
# ✅ Collected 300 headlines from 100 tickers
#
# Sample headlines:
#   AAPL: Apple Stock (AAPL) Before the US Market Open (Dec. 15, 2025): Key News, Analyst Targets, a...
#   AAPL: Apple Stock Gets Three Price-Target Hikes. Here’s Why. - Investor's Business Daily...
#   AAPL: Apple Inc. Stock (AAPL) Opinions on AI Developments and Leadership Changes - Quiver Quanti...
#   MSFT: MSFT vs. GOOGL vs. NVDA: Which ‘Strong Buy’ Mega-Cap Stock Has the Highest Upside Potentia...
#   MSFT: Microsoft Stock (MSFT) After Hours on Dec. 12, 2025: What Investors Need to Know Before th...
#   MSFT: Better (Almost) $4 Trillion AI Stock to Buy Now: Microsoft or Alphabet - The Motley Fool...
#   NVDA: ‘Dreams Won’t Pay Forever,’ Says Investor About Nvidia Stock - TipRanks...
#   NVDA: Looking for the Next NVDA? Top Analyst Flags 3 Quantum Computing Stocks to Buy (RGTI, IONQ...
#   NVDA: The Saturday Spread: Here’s How to Properly Trade the Nvidia (NVDA) Stock Discount - Yahoo...
#   AMD: Why AMD (AMD) Shares Are Sliding Today - Yahoo Finance...

# %%
# Load FinBERT model for financial sentiment analysis (FORCE safetensors to avoid CVE)
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

print("Loading FinBERT model with safetensors (avoiding torch.load CVE)...")
device = 0 if torch.cuda.is_available() else -1

# FORCE safetensors loading by loading model separately with use_safetensors=True
model_name = "yiyanghkust/finbert-tone"

print("  Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(model_name)

print("  Loading model with safetensors (bypassing pytorch_model.bin)...")
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    use_safetensors=True,  # FORCE safetensors, skip pytorch_model.bin
    ignore_mismatched_sizes=False
)

# Move to GPU if available
if device == 0:
    model = model.to('cuda')
    print(f"  ✅ Model moved to GPU")

# Create pipeline with pre-loaded model
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device,
    truncation=True,
    max_length=512
)

print(f"\n✅ Model loaded on {'GPU' if device == 0 else 'CPU'}")

# Test GPU speed
test_texts = [
    "Company reports record earnings with 50% revenue growth",
    "Stock plunges on disappointing guidance and regulatory concerns",
    "New product launch expected to drive significant market share gains"
]

start = time.time()
test_results = sentiment_pipeline(test_texts, batch_size=3)
elapsed = time.time() - start

print(f"\n⚡ GPU Speed Test: {len(test_texts)} texts in {elapsed:.3f}s ({len(test_texts)/elapsed:.1f} texts/sec)")
print("\nSample results:")
for text, result in zip(test_texts, test_results):
    print(f"  {result['label']}: {text[:50]}...")
# Out:
# Loading FinBERT model with safetensors (avoiding torch.load CVE)...
#   Loading tokenizer...
#   Loading model with safetensors (bypassing pytorch_model.bin)...
# Device set to use cuda:0
#   ✅ Model moved to GPU
#
# ✅ Model loaded on GPU
#
# ⚡ GPU Speed Test: 3 texts in 0.086s (34.9 texts/sec)
#
# Sample results:
#   Positive: Company reports record earnings with 50% revenue g...
#   Negative: Stock plunges on disappointing guidance and regula...
#   Positive: New product launch expected to drive significant m...

# %%
def analyze_sentiment_batch(news_list, batch_size=32):
    """
    GPU-accelerated batch sentiment analysis
    Takes list of news items and returns sentiment scores
    """
    if not news_list or len(news_list) == 0:
        return []
    
    # Extract headlines
    texts = [item.get('title', '') for item in news_list if item.get('title')]
    
    if not texts:
        return []
    
    # Batch process on GPU
    print(f"🔄 Analyzing {len(texts)} headlines on GPU...")
    start = time.time()
    results = sentiment_pipeline(texts, batch_size=batch_size)
    elapsed = time.time() - start
    
    print(f"✅ Processed {len(texts)} texts in {elapsed:.2f}s ({len(texts)/elapsed:.1f} texts/sec)")
    
    # Combine with original data
    for i, item in enumerate(news_list[:len(results)]):
        if 'title' in item:
            sentiment = results[i]
            item['sentiment_label'] = sentiment['label']
            item['sentiment_score'] = sentiment.get('score', 0)
            # Convert to numeric: positive=1, negative=-1, neutral=0
            label = sentiment['label'].lower()
            if 'pos' in label:
                item['sentiment_numeric'] = sentiment.get('score', 0)
            elif 'neg' in label:
                item['sentiment_numeric'] = -sentiment.get('score', 0)
            else:
                item['sentiment_numeric'] = 0
    
    return news_list

# Apply sentiment to the batch news collected
if 'valid_news_df' in globals() and len(valid_news_df) > 0:
    print("\n🚀 Running GPU sentiment analysis on batch news...")
    analyzed_news = analyze_sentiment_batch(valid_news_df.to_dict(orient='records'), batch_size=32)
    sentiment_df = pd.DataFrame(analyzed_news)
    print(f"\n✅ Sentiment annotated: {len(sentiment_df)} headlines")
    print("Sample with sentiment:")
    print(sentiment_df[['ticker', 'sentiment_label', 'sentiment_score', 'title']].head(10))
# Out:
# 🚀 Running GPU sentiment analysis on batch news...
# 🔄 Analyzing 300 headlines on GPU...
# ✅ Processed 300 texts in 0.59s (507.4 texts/sec)
#
# ✅ Sentiment annotated: 300 headlines
# Sample with sentiment:
#   ticker sentiment_label  sentiment_score  \
# 0   AAPL         Neutral         0.999952
# 1   AAPL         Neutral         0.999951
# 2   AAPL         Neutral         0.999958
# 3   MSFT        Positive         1.000000
# 4   MSFT         Neutral         0.999946
# 5   MSFT        Positive         0.997819
# 6   NVDA         Neutral         0.999972
# 7   NVDA        Positive         0.957036
# 8   NVDA         Neutral         0.999958
# 9    AMD        Negative         0.907116
#
#                                                title
# 0  Apple Stock (AAPL) Before the US Market Open (...
# 1  Apple Stock Gets Three Price-Target Hikes. Her...
# 2  Apple Inc. Stock (AAPL) Opinions on AI Develop...
# 3  MSFT vs. GOOGL vs. NVDA: Which ‘Strong Buy’ Me...
# 4  Microsoft Stock (MSFT) After Hours on Dec. 12,...
# 5  Better (Almost) $4 Trillion AI Stock to Buy No...
# 6  ‘Dreams Won’t Pay Forever,’ Says Investor Abou...
# 7  Looking for the Next NVDA? Top Analyst Flags 3...
# 8  The Saturday Spread: Here’s How to Properly Tr...
# 9  Why AMD (AMD) Shares Are Sliding Today - Yahoo...

# %%
def collect_all_data_for_ticker(ticker):
    """
    Master function: Collect ALL data for a single ticker
    Returns: dict with OHLCV, fundamentals, insider, sentiment
    """
    print(f"📊 {ticker}...", end=' ')
    
    data = {'ticker': ticker}
    
    try:
        # 1. OHLCV from yfinance
        ohlcv = yf.download(ticker, period='2y', progress=False)
        if not ohlcv.empty:
            data['bars_count'] = len(ohlcv)
            data['last_price'] = float(ohlcv['Close'].iloc[-1])
            data['avg_volume'] = float(ohlcv['Volume'].mean())
            data['volatility'] = float(ohlcv['Close'].pct_change().std() * np.sqrt(252))
            # Momentum
            data['return_1m'] = float((ohlcv['Close'].iloc[-1] / ohlcv['Close'].iloc[-20] - 1) * 100)
            data['return_3m'] = float((ohlcv['Close'].iloc[-1] / ohlcv['Close'].iloc[-60] - 1) * 100)
        
        time.sleep(0.3)
        
        # 2. Fundamentals from multi-source collector
        fundamentals = collect_fundamentals_multisource(ticker)
        # Extract just the values, not the source attribution
        for field, field_data in fundamentals.items():
            if field != 'ticker' and isinstance(field_data, dict):
                data[field] = field_data.get('value')
        time.sleep(1)
        
        # 3. Insider trades from SEC
        insider = get_sec_insider_trades(ticker)
        data['insider_trades_count'] = insider.get('insider_trades', 0)
        time.sleep(2)
        
        # 4. News sentiment
        news = scrape_google_news(ticker, max_articles=5)
        if news and len(news) > 0:
            analyzed = analyze_sentiment_batch(news, batch_size=5)
            if analyzed:
                sentiments = [n.get('sentiment_numeric', 0) for n in analyzed if 'sentiment_numeric' in n]
                data['news_count'] = len(analyzed)
                data['avg_sentiment'] = np.mean(sentiments) if sentiments else 0
                data['sentiment_std'] = np.std(sentiments) if len(sentiments) > 1 else 0
        time.sleep(0.5)
        
        print("✓")
        
    except Exception as e:
        print(f"✗ ({str(e)[:30]})")
        data['error'] = str(e)
    
    return data

# TEST on 10 tickers
print("\\n🔬 FULL DATA COLLECTION TEST (10 tickers)\\n")
test_batch = TICKERS[:10]
all_ticker_data = []

for ticker in test_batch:
    ticker_data = collect_all_data_for_ticker(ticker)
    all_ticker_data.append(ticker_data)

# Convert to dataframe
results_df = pd.DataFrame(all_ticker_data)
print(f"\\n✅ Collected data for {len(results_df)} tickers")
print(f"\\nColumns collected: {list(results_df.columns)}")
print("\\nSample results (all available columns):")
# Show only columns that exist
available_cols = ['ticker', 'last_price', 'return_1m']
available_cols.extend([c for c in ['avg_sentiment', 'insider_trades_count', 'market_cap', 'trailing_pe'] if c in results_df.columns])
print(results_df[available_cols].head())
# Out:
# \n🔬 FULL DATA COLLECTION TEST (10 tickers)\n
# 📊 AAPL...
# 2025-12-14 22:13:18,646 - INFO - === Starting collection for AAPL ===
# 2025-12-14 22:13:18,900 - INFO - [AAPL] Retrieved 9 fields from yfinance
# 2025-12-14 22:13:18,901 - INFO - [AAPL] Trying fmp fallback...
# 2025-12-14 22:13:19,116 - WARNING - [AAPL] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/AAPL?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:13:19,118 - INFO - [AAPL] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:13:19,338 - INFO - [AAPL] Found PEG ratio from alpha_vantage
# 2025-12-14 22:13:34,341 - INFO - === Completed AAPL. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.15s (34.0 texts/sec)
# ✓
# 📊 MSFT...
# 2025-12-14 22:13:39,644 - INFO - === Starting collection for MSFT ===
# 2025-12-14 22:13:39,888 - INFO - [MSFT] Retrieved 9 fields from yfinance
# 2025-12-14 22:13:39,888 - INFO - [MSFT] Trying fmp fallback...
# 2025-12-14 22:13:40,094 - WARNING - [MSFT] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/MSFT?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:13:40,096 - INFO - [MSFT] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:13:40,333 - INFO - [MSFT] Found PEG ratio from alpha_vantage
# 2025-12-14 22:13:55,335 - INFO - === Completed MSFT. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.12s (42.5 texts/sec)
# ✓
# 📊 NVDA...
# 2025-12-14 22:14:00,637 - INFO - === Starting collection for NVDA ===
# 2025-12-14 22:14:00,932 - INFO - [NVDA] Retrieved 9 fields from yfinance
# 2025-12-14 22:14:00,933 - INFO - [NVDA] Trying fmp fallback...
# 2025-12-14 22:14:01,637 - WARNING - [NVDA] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/NVDA?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:14:01,639 - INFO - [NVDA] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:14:02,040 - INFO - [NVDA] Found PEG ratio from alpha_vantage
# 2025-12-14 22:14:17,042 - INFO - === Completed NVDA. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.20s (25.1 texts/sec)
# ✓
# 📊 AMD...
# 2025-12-14 22:14:22,389 - INFO - === Starting collection for AMD ===
# 2025-12-14 22:14:22,596 - INFO - [AMD] Retrieved 9 fields from yfinance
# 2025-12-14 22:14:22,596 - INFO - [AMD] Trying fmp fallback...
# 2025-12-14 22:14:22,829 - WARNING - [AMD] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/AMD?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:14:22,831 - INFO - [AMD] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:14:23,051 - INFO - [AMD] Found PEG ratio from alpha_vantage
# 2025-12-14 22:14:38,054 - INFO - === Completed AMD. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.17s (29.8 texts/sec)
# ✓
# 📊 AVGO...
# 2025-12-14 22:14:43,491 - INFO - === Starting collection for AVGO ===
# 2025-12-14 22:14:43,732 - INFO - [AVGO] Retrieved 9 fields from yfinance
# 2025-12-14 22:14:43,732 - INFO - [AVGO] Trying fmp fallback...
# 2025-12-14 22:14:43,948 - WARNING - [AVGO] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/AVGO?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:14:43,950 - INFO - [AVGO] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:14:44,218 - INFO - [AVGO] Found PEG ratio from alpha_vantage
# 2025-12-14 22:14:59,221 - INFO - === Completed AVGO. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.11s (45.7 texts/sec)
# ✓
# 📊 MSTR...
# 2025-12-14 22:15:04,783 - INFO - === Starting collection for MSTR ===
# 2025-12-14 22:15:04,996 - INFO - [MSTR] Retrieved 9 fields from yfinance
# 2025-12-14 22:15:04,997 - INFO - [MSTR] Trying fmp fallback...
# 2025-12-14 22:15:05,211 - WARNING - [MSTR] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/MSTR?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:15:05,213 - INFO - [MSTR] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:15:05,481 - INFO - [MSTR] Found PEG ratio from alpha_vantage
# 2025-12-14 22:15:20,483 - INFO - === Completed MSTR. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.27s (18.5 texts/sec)
# ✓
# 📊 IONQ...
# 2025-12-14 22:15:26,382 - INFO - === Starting collection for IONQ ===
# 2025-12-14 22:15:26,597 - INFO - [IONQ] Retrieved 8 fields from yfinance
# 2025-12-14 22:15:26,598 - INFO - [IONQ] Trying fmp fallback...
# 2025-12-14 22:15:26,853 - WARNING - [IONQ] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/IONQ?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:15:26,854 - INFO - [IONQ] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:15:42,086 - INFO - === Completed IONQ. Fields found: 8/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.12s (43.5 texts/sec)
# ✓
# 📊 GOOGL...
# 2025-12-14 22:15:47,291 - INFO - === Starting collection for GOOGL ===
# 2025-12-14 22:15:47,539 - INFO - [GOOGL] Retrieved 9 fields from yfinance
# 2025-12-14 22:15:47,540 - INFO - [GOOGL] Trying fmp fallback...
# 2025-12-14 22:15:47,761 - WARNING - [GOOGL] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/GOOGL?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:15:47,763 - INFO - [GOOGL] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:15:48,003 - INFO - [GOOGL] Found PEG ratio from alpha_vantage
# 2025-12-14 22:16:03,005 - INFO - === Completed GOOGL. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.12s (42.0 texts/sec)
# ✓
# 📊 META...
# 2025-12-14 22:16:08,665 - INFO - === Starting collection for META ===
# 2025-12-14 22:16:08,890 - INFO - [META] Retrieved 9 fields from yfinance
# 2025-12-14 22:16:08,891 - INFO - [META] Trying fmp fallback...
# 2025-12-14 22:16:09,168 - WARNING - [META] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/META?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:16:09,170 - INFO - [META] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:16:09,395 - INFO - [META] Found PEG ratio from alpha_vantage
# 2025-12-14 22:16:24,397 - INFO - === Completed META. Fields found: 10/10 ===
#
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.15s (33.8 texts/sec)
# ✓
# 📊 TSLA...
# 2025-12-14 22:16:29,773 - INFO - === Starting collection for TSLA ===
# 2025-12-14 22:16:30,027 - INFO - [TSLA] Retrieved 9 fields from yfinance
# 2025-12-14 22:16:30,028 - INFO - [TSLA] Trying fmp fallback...
# 2025-12-14 22:16:30,315 - WARNING - [TSLA] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/TSLA?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 22:16:30,316 - INFO - [TSLA] Trying alpha_vantage for PEG ratio...
# 2025-12-14 22:16:30,593 - INFO - [TSLA] Found PEG ratio from alpha_vantage
# 2025-12-14 22:16:45,595 - INFO - === Completed TSLA. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.05s (92.2 texts/sec)
# ✓
# \n✅ Collected data for 10 tickers
# \nColumns collected: ['ticker', 'bars_count', 'last_price', 'avg_volume', 'volatility', 'return_1m', 'return_3m', 'market_cap', 'trailing_pe', 'forward_pe', 'peg_ratio', 'short_pct', 'insider_pct', 'institution_pct', 'beta', 'price_to_book', 'price_to_sales', 'insider_trades_count', 'news_count', 'avg_sentiment', 'sentiment_std']
# \nSample results (all available columns):
#   ticker  last_price  return_1m  avg_sentiment  insider_trades_count  \
# 0   AAPL  278.279999   2.154838       0.000000                     8
# 1   MSFT  478.529999  -6.028138       0.399564                    10
# 2   NVDA  175.020004  -7.961428       0.391407                    10
# 3    AMD  210.779999 -14.598274      -0.256164                     8
# 4   AVGO  359.929993   5.101326       0.200000                     8
#
#       market_cap  trailing_pe
# 0  4129783545856    37.302948
# 1  3556993138688    34.010662
# 2  4261212061696    43.321785
# 3   343158620160   109.781250
# 4  1699720724480    75.141960

# %%
def calculate_composite_score(df):
    """
    Calculate multi-factor score for ranking stocks
    
    Factors:
    1. Momentum (30%): 1-month and 3-month returns
    2. Sentiment (20%): News sentiment score
    3. Insider Activity (15%): Recent Form 4 filings
    4. Volatility (15%): Higher vol = more opportunity
    5. Value (10%): P/E ratio (lower better)
    6. Short Interest (10%): High short % = squeeze potential
    """
    
    scores = pd.DataFrame(index=df.index)
    
    # 1. Momentum Score (30%)
    df['return_1m_clean'] = pd.to_numeric(df['return_1m'], errors='coerce')
    df['return_3m_clean'] = pd.to_numeric(df['return_3m'], errors='coerce')
    
    scores['momentum'] = (
        df['return_1m_clean'].fillna(0) * 0.6 + 
        df['return_3m_clean'].fillna(0) * 0.4
    )
    
    # 2. Sentiment Score (20%)
    scores['sentiment'] = df['avg_sentiment'].fillna(0) * 100
    
    # 3. Insider Activity Score (15%)
    scores['insider'] = df['insider_trades_count'].fillna(0) * 10
    
    # 4. Volatility Score (15%) - normalized
    df['volatility_clean'] = pd.to_numeric(df['volatility'], errors='coerce')
    scores['volatility'] = df['volatility_clean'].fillna(0) * 100
    
    # 5. Value Score (10%) - inverse P/E
    df['pe_clean'] = df['trailing_pe'].replace('N/A', np.nan)
    df['pe_clean'] = pd.to_numeric(df['pe_clean'], errors='coerce')
    scores['value'] = 100 / (df['pe_clean'].fillna(50) + 1)  # Lower P/E = higher score
    
    # 6. Short Interest Score (10%)
    df['short_clean'] = df['short_pct'].replace('N/A', np.nan)
    df['short_clean'] = pd.to_numeric(df['short_clean'].str.rstrip('%'), errors='coerce')
    scores['short_squeeze'] = df['short_clean'].fillna(0) * 2
    
    # Normalize all scores to 0-100
    for col in scores.columns:
        min_val = scores[col].min()
        max_val = scores[col].max()
        if max_val > min_val:
            scores[col] = (scores[col] - min_val) / (max_val - min_val) * 100
    
    # Composite score with weights
    weights = {
        'momentum': 0.30,
        'sentiment': 0.20,
        'insider': 0.15,
        'volatility': 0.15,
        'value': 0.10,
        'short_squeeze': 0.10
    }
    
    df['composite_score'] = sum(scores[factor] * weight for factor, weight in weights.items())
    
    # Add individual factor scores
    for factor in scores.columns:
        df[f'{factor}_score'] = scores[factor]
    
    return df

# Apply scoring to test data
if len(results_df) > 0:
    print("🎯 Calculating composite scores...")
    scored_df = calculate_composite_score(results_df.copy())
    
    # Rank by score
    scored_df = scored_df.sort_values('composite_score', ascending=False)
    
    print("\n🏆 TOP RANKED TICKERS:")
    print(scored_df[['ticker', 'composite_score', 'momentum_score', 
                     'sentiment_score', 'insider_score', 'last_price']].head(10))
# Out:
# 🎯 Calculating composite scores...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 73
#      71 if len(results_df) > 0:
#      72     print("🎯 Calculating composite scores...")
# ---> 73     scored_df = calculate_composite_score(results_df.copy())
#      75     # Rank by score
#      76     scored_df = scored_df.sort_values('composite_score', ascending=False)
#
# Cell In[31], line 42, in calculate_composite_score(df)
#      40 # 6. Short Interest Score (10%)
#      41 df['short_clean'] = df['short_pct'].replace('N/A', np.nan)
# ---> 42 df['short_clean'] = pd.to_numeric(df['short_clean'].str.rstrip('%'), errors='coerce')
#      43 scores['short_squeeze'] = df['short_clean'].fillna(0) * 2
#      45 # Normalize all scores to 0-100
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import json

class FundamentalDataBatchProcessor:
    """Batch processor with checkpointing for 353 tickers. Runs in 45-60 minutes."""
    
    def __init__(self, tickers, max_workers=5, checkpoint_interval=50):
        self.tickers = tickers
        self.max_workers = max_workers
        self.checkpoint_interval = checkpoint_interval
        self.results = []
        self.failed_tickers = []
        self.progress_file = "data/fundamentals_checkpoint.json"
        self.final_output_file = f"data/results/fundamentals_batch_{datetime.now().strftime('%Y%m%d_%H%M')}.csv"
        
        # Create directories if needed
        os.makedirs('data/results', exist_ok=True)

    def load_checkpoint(self):
        """Load previous progress from checkpoint file."""
        try:
            with open(self.progress_file, 'r') as f:
                saved = json.load(f)
                self.results = saved.get('results', [])
                processed_set = {r['ticker'] for r in self.results}
                # Only process new tickers
                self.tickers = [t for t in self.tickers if t not in processed_set]
                logger.info(f"Loaded checkpoint. {len(self.results)} already processed. {len(self.tickers)} remaining.")
        except FileNotFoundError:
            logger.info("No checkpoint found. Starting fresh.")
        except Exception as e:
            logger.error(f"Error loading checkpoint: {e}. Starting fresh.")

    def save_checkpoint(self):
        """Save current progress to checkpoint file."""
        try:
            checkpoint_data = {
                'timestamp': datetime.utcnow().isoformat(),
                'results': self.results,
                'failed': self.failed_tickers
            }
            with open(self.progress_file, 'w') as f:
                json.dump(checkpoint_data, f, indent=2)
            logger.info(f"Checkpoint saved. {len(self.results)} processed, {len(self.failed_tickers)} failed.")
        except Exception as e:
            logger.error(f"Failed to save checkpoint: {e}")

    def process_single(self, ticker: str):
        """Wrapper with retry logic (exponential backoff)."""
        max_retries = 3
        for attempt in range(max_retries):
            try:
                result = collect_fundamentals_multisource(ticker)
                return result
            except Exception as e:
                if attempt == max_retries - 1:
                    raise e
                wait_time = (2 ** attempt) + 1
                logger.warning(f"[{ticker}] Attempt {attempt+1} failed. Retrying in {wait_time}s.")
                time.sleep(wait_time)

    def run_batch(self):
        """Main batch processor with parallel execution and progress tracking."""
        logger.info(f"Starting batch processing for {len(self.tickers)} tickers with {self.max_workers} workers.")
        self.load_checkpoint()

        if len(self.tickers) == 0:
            logger.info("All tickers already processed!")
            self.save_results_to_csv(0)
            return

        total = len(self.tickers)
        processed = 0
        start_time = time.time()

        with ThreadPoolExecutor(max_workers=self.max_workers) as executor:
            future_to_ticker = {executor.submit(self.process_single, ticker): ticker for ticker in self.tickers}

            for future in as_completed(future_to_ticker):
                ticker = future_to_ticker[future]
                try:
                    result = future.result(timeout=60)
                    self.results.append(result)
                    processed += 1

                    # Progress every 10 tickers
                    if processed % 10 == 0:
                        elapsed = time.time() - start_time
                        eta = (elapsed / processed) * (total - processed) if processed > 0 else 0
                        logger.info(f"Progress: {processed}/{total} ({processed/total:.1%}). ETA: {eta/60:.1f} min.")

                    # Checkpoint every 50 tickers
                    if processed % self.checkpoint_interval == 0:
                        self.save_checkpoint()

                except Exception as e:
                    logger.error(f"Error processing {ticker}: {e}")
                    self.failed_tickers.append({'ticker': ticker, 'error': str(e)})

        elapsed_total = time.time() - start_time
        self.save_results_to_csv(elapsed_total)
        self.save_checkpoint()
        self.print_summary(elapsed_total)

    def save_results_to_csv(self, elapsed_time):
        """Flatten and save results to CSV with source attribution."""
        if not self.results:
            logger.warning("No results to save.")
            return

        flat_rows = []
        for r in self.results:
            flat_row = {'ticker': r['ticker']}
            for field in ['market_cap', 'trailing_pe', 'forward_pe', 'peg_ratio',
                          'short_pct', 'insider_pct', 'institution_pct', 'beta', 'price_to_book', 'price_to_sales']:
                data = r.get(field, {})
                flat_row[f"{field}_value"] = data.get('value')
                flat_row[f"{field}_source"] = data.get('source')
            flat_rows.append(flat_row)

        df = pd.DataFrame(flat_rows)
        
        # Add metadata
        metadata = (
            f"# Generated: {datetime.utcnow().isoformat()}\n"
            f"# Total tickers: {len(self.results) + len(self.failed_tickers)}\n"
            f"# Successfully processed: {len(self.results)}\n"
            f"# Failed: {len(self.failed_tickers)}\n"
            f"# Processing time: {elapsed_time:.1f} seconds ({elapsed_time/60:.1f} minutes)\n"
            f"# Success rate: {len(self.results)/(len(self.results)+len(self.failed_tickers)):.1%}\n"
        )

        with open(self.final_output_file, 'w') as f:
            f.write(metadata)
            df.to_csv(f, index=False)

        logger.info(f"Results saved to {self.final_output_file}")

    def print_summary(self, elapsed_time):
        """Print final summary report."""
        print("\n" + "="*60)
        print("BATCH PROCESSING SUMMARY")
        print("="*60)
        print(f"Total tickers attempted: {len(self.results) + len(self.failed_tickers)}")
        print(f"Successfully processed:  {len(self.results)}")
        print(f"Failed:                  {len(self.failed_tickers)}")
        print(f"Total time:              {elapsed_time/60:.1f} minutes")
        if len(self.results) + len(self.failed_tickers) > 0:
            success_rate = len(self.results)/(len(self.results) + len(self.failed_tickers))
            print(f"Success rate:            {success_rate:.1%}")
        print("="*60)

# ==================== RUN ON ALL 353 TICKERS ====================
# UNCOMMENT BELOW TO RUN FULL BATCH (will take 45-60 minutes)

print("⚠️ Full batch processing: 353 tickers, 45-60 minutes")
print("   Checkpoints saved every 50 tickers for recovery\n")

# Uncomment to run:
# processor = FundamentalDataBatchProcessor(
#     tickers=TICKERS,
#     max_workers=5,
#     checkpoint_interval=50
# )
# processor.run_batch()

# For now, test on 20 tickers to validate:
print("🔄 Testing batch processor on first 20 tickers...")
processor = FundamentalDataBatchProcessor(
    tickers=TICKERS[:20],
    max_workers=3,
    checkpoint_interval=50
)
processor.run_batch()
print("\n✅ Batch processor test complete!")
# Out:
# 2025-12-14 22:58:04,318 - INFO - Starting batch processing for 20 tickers with 3 workers.
# 2025-12-14 22:58:04,320 - INFO - Loaded checkpoint. 20 already processed. 0 remaining.
# 2025-12-14 22:58:04,321 - INFO - All tickers already processed!
# 2025-12-14 22:58:04,327 - INFO - Results saved to data/results/fundamentals_batch_20251214_2258.csv
# ⚠️ Full batch processing: 353 tickers, 45-60 minutes
#    Checkpoints saved every 50 tickers for recovery
#
# 🔄 Testing batch processor on first 20 tickers...
#
# ✅ Batch processor test complete!

# %%
def get_sec_insider_trades(ticker):
    """
    Get insider trading data from SEC EDGAR using their JSON API
    100% free, no API key needed
    """
    try:
        # Step 1: Get CIK (company ID) from ticker
        cik_lookup_url = "https://www.sec.gov/files/company_tickers.json"
        cik_data = requests.get(cik_lookup_url, headers=HEADERS, timeout=10).json()
        
        cik = None
        for entry in cik_data.values():
            if entry['ticker'].upper() == ticker.upper():
                cik = str(entry['cik_str']).zfill(10)  # Pad with zeros
                break
        
        if not cik:
            return {'ticker': ticker, 'insider_trades': 0, 'recent_filings': []}
        
        # Step 2: Get filing history from SEC
        filing_url = f"https://data.sec.gov/submissions/CIK{cik}.json"
        filing_data = requests.get(filing_url, headers=HEADERS, timeout=10).json()
        
        # Step 3: Filter for Form 4 (insider trades) and 8-K (major events)
        filings_df = pd.DataFrame(filing_data['filings']['recent'])
        insider_filings = filings_df[filings_df['form'].isin(['4', '8-K'])].head(10)
        
        recent_trades = []
        for _, filing in insider_filings.iterrows():
            recent_trades.append({
                'date': filing['filingDate'],
                'form': filing['form'],
                'description': filing.get('primaryDocDescription', 'N/A')
            })
        
        return {
            'ticker': ticker,
            'cik': cik,
            'insider_trades': len(insider_filings[insider_filings['form'] == '4']),
            'recent_filings': recent_trades
        }
        
    except Exception as e:
        return {'ticker': ticker, 'error': str(e), 'insider_trades': 0}

# Test on 3 tickers
print("🔄 Testing SEC insider scraper...")
test_insiders = []
for ticker in ['NVDA', 'IONQ', 'HOOD']:
    print(f"  Fetching {ticker} SEC filings...")
    insider = get_sec_insider_trades(ticker)
    test_insiders.append(insider)
    time.sleep(2)  # SEC rate limit

for ins in test_insiders:
    print(f"\n{ins['ticker']}: {ins.get('insider_trades', 0)} recent Form 4 filings")
    if 'recent_filings' in ins:
        for filing in ins['recent_filings'][:3]:
            print(f"  - {filing['date']} [{filing['form']}]")
# Out:
# 🔄 Testing SEC insider scraper...
#   Fetching NVDA SEC filings...
#   Fetching IONQ SEC filings...
#   Fetching HOOD SEC filings...
#
# NVDA: 10 recent Form 4 filings
#   - 2025-12-12 [4]
#   - 2025-12-12 [4]
#   - 2025-12-12 [4]
#
# IONQ: 6 recent Form 4 filings
#   - 2025-12-12 [4]
#   - 2025-12-12 [4]
#   - 2025-11-21 [4]
#
# HOOD: 10 recent Form 4 filings
#   - 2025-12-12 [4]
#   - 2025-12-09 [4]
#   - 2025-12-05 [4]

# %%
def scrape_google_news(ticker, max_articles=5):
    """
    Scrape Google News RSS feed for ticker
    Free, no API key needed
    """
    url = f"https://news.google.com/rss/search?q={ticker}+stock&hl=en-US&gl=US&ceid=US:en"
    
    try:
        resp = requests.get(url, headers=HEADERS, timeout=10)
        soup = BeautifulSoup(resp.content, features='xml')
        
        news_items = []
        for item in soup.findAll('item')[:max_articles]:
            news_items.append({
                'ticker': ticker,
                'title': item.title.text if item.title else '',
                'published': item.pubDate.text if item.pubDate else '',
                'link': item.link.text if item.link else ''
            })
        
        return news_items
        
    except Exception as e:
        return [{'ticker': ticker, 'error': str(e)}]

# Batch news scraping across many tickers (with rate limiting)
print("🔄 Collecting Google News across the universe (up to 3 per ticker)...")
news_batch = []
max_per_ticker = 3

for i, tk in enumerate(TICKERS[:100], 1):  # start with first 100 to validate
    if i % 20 == 0:
        print(f"  Progress: {i} tickers")
    items = scrape_google_news(tk, max_articles=max_per_ticker)
    news_batch.extend(items)
    time.sleep(0.5)  # polite delay

news_df = pd.DataFrame(news_batch)
valid_news_df = news_df[news_df['title'].fillna('') != ''] if len(news_df) else pd.DataFrame()
print(f"\n✅ Collected {len(valid_news_df)} headlines from {min(100, len(TICKERS))} tickers")
if len(valid_news_df) > 0:
    print("\nSample headlines:")
    for _, row in valid_news_df.head(10).iterrows():
        print(f"  {row['ticker']}: {row['title'][:90]}...")
# Out:
# 🔄 Collecting Google News across the universe (up to 3 per ticker)...
#   Progress: 20 tickers
#   Progress: 40 tickers
#   Progress: 60 tickers
#   Progress: 80 tickers
#   Progress: 100 tickers
#
# ✅ Collected 300 headlines from 100 tickers
#
# Sample headlines:
#   AAPL: Apple Stock (AAPL) Before the US Market Open (Dec. 15, 2025): Key News, Analyst Targets, a...
#   AAPL: Apple Stock Gets Three Price-Target Hikes. Here’s Why. - Investor's Business Daily...
#   AAPL: Apple Inc. Stock (AAPL) Opinions on AI Developments and Leadership Changes - Quiver Quanti...
#   MSFT: MSFT vs. GOOGL vs. NVDA: Which ‘Strong Buy’ Mega-Cap Stock Has the Highest Upside Potentia...
#   MSFT: Microsoft Stock (MSFT) After Hours on Dec. 12, 2025: What Investors Need to Know Before th...
#   MSFT: Better (Almost) $4 Trillion AI Stock to Buy Now: Microsoft or Alphabet - The Motley Fool...
#   NVDA: Could Nvidia Be the Most Undervalued Stock in AI Right Now and Be Ready to Soar in 2026? -...
#   NVDA: The Saturday Spread: Here’s How to Properly Trade the Nvidia (NVDA) Stock Discount - Yahoo...
#   NVDA: Nvidia Stock (NVDA) Before the Market Opens Dec. 15, 2025: Latest News, Key Catalysts, Ana...
#   AMD: Why AMD (AMD) Shares Are Sliding Today - Yahoo Finance...

# %%
# Load FinBERT model for financial sentiment analysis (FORCE safetensors to avoid CVE)
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification

print("Loading FinBERT model with safetensors (avoiding torch.load CVE)...")
device = 0 if torch.cuda.is_available() else -1

# FORCE safetensors loading by loading model separately with use_safetensors=True
model_name = "yiyanghkust/finbert-tone"

print("  Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(model_name)

print("  Loading model with safetensors (bypassing pytorch_model.bin)...")
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    use_safetensors=True,  # FORCE safetensors, skip pytorch_model.bin
    ignore_mismatched_sizes=False
)

# Move to GPU if available
if device == 0:
    model = model.to('cuda')
    print(f"  ✅ Model moved to GPU")

# Create pipeline with pre-loaded model
sentiment_pipeline = pipeline(
    "sentiment-analysis",
    model=model,
    tokenizer=tokenizer,
    device=device,
    truncation=True,
    max_length=512
)

print(f"\n✅ Model loaded on {'GPU' if device == 0 else 'CPU'}")

# Test GPU speed
test_texts = [
    "Company reports record earnings with 50% revenue growth",
    "Stock plunges on disappointing guidance and regulatory concerns",
    "New product launch expected to drive significant market share gains"
]

start = time.time()
test_results = sentiment_pipeline(test_texts, batch_size=3)
elapsed = time.time() - start

print(f"\n⚡ GPU Speed Test: {len(test_texts)} texts in {elapsed:.3f}s ({len(test_texts)/elapsed:.1f} texts/sec)")
print("\nSample results:")
for text, result in zip(test_texts, test_results):
    print(f"  {result['label']}: {text[:50]}...")
# Out:
# Loading FinBERT model with safetensors (avoiding torch.load CVE)...
#   Loading tokenizer...
#   Loading model with safetensors (bypassing pytorch_model.bin)...
# Device set to use cuda:0
#   ✅ Model moved to GPU
#
# ✅ Model loaded on GPU
#
# ⚡ GPU Speed Test: 3 texts in 0.041s (73.1 texts/sec)
#
# Sample results:
#   Positive: Company reports record earnings with 50% revenue g...
#   Negative: Stock plunges on disappointing guidance and regula...
#   Positive: New product launch expected to drive significant m...

# %%
def analyze_sentiment_batch(news_list, batch_size=32):
    """
    GPU-accelerated batch sentiment analysis
    Takes list of news items and returns sentiment scores
    """
    if not news_list or len(news_list) == 0:
        return []
    
    # Extract headlines
    texts = [item.get('title', '') for item in news_list if item.get('title')]
    
    if not texts:
        return []
    
    # Batch process on GPU
    print(f"🔄 Analyzing {len(texts)} headlines on GPU...")
    start = time.time()
    results = sentiment_pipeline(texts, batch_size=batch_size)
    elapsed = time.time() - start
    
    print(f"✅ Processed {len(texts)} texts in {elapsed:.2f}s ({len(texts)/elapsed:.1f} texts/sec)")
    
    # Combine with original data
    for i, item in enumerate(news_list[:len(results)]):
        if 'title' in item:
            sentiment = results[i]
            item['sentiment_label'] = sentiment['label']
            item['sentiment_score'] = sentiment.get('score', 0)
            # Convert to numeric: positive=1, negative=-1, neutral=0
            label = sentiment['label'].lower()
            if 'pos' in label:
                item['sentiment_numeric'] = sentiment.get('score', 0)
            elif 'neg' in label:
                item['sentiment_numeric'] = -sentiment.get('score', 0)
            else:
                item['sentiment_numeric'] = 0
    
    return news_list

# Apply sentiment to the batch news collected
if 'valid_news_df' in globals() and len(valid_news_df) > 0:
    print("\n🚀 Running GPU sentiment analysis on batch news...")
    analyzed_news = analyze_sentiment_batch(valid_news_df.to_dict(orient='records'), batch_size=32)
    sentiment_df = pd.DataFrame(analyzed_news)
    print(f"\n✅ Sentiment annotated: {len(sentiment_df)} headlines")
    print("Sample with sentiment:")
    print(sentiment_df[['ticker', 'sentiment_label', 'sentiment_score', 'title']].head(10))
# Out:
# 🚀 Running GPU sentiment analysis on batch news...
# 🔄 Analyzing 300 headlines on GPU...
# ✅ Processed 300 texts in 0.71s (420.9 texts/sec)
#
# ✅ Sentiment annotated: 300 headlines
# Sample with sentiment:
#   ticker sentiment_label  sentiment_score  \
# 0   AAPL         Neutral         0.999952
# 1   AAPL         Neutral         0.999951
# 2   AAPL         Neutral         0.999958
# 3   MSFT        Positive         1.000000
# 4   MSFT         Neutral         0.999946
# 5   MSFT        Positive         0.997819
# 6   NVDA        Positive         0.999887
# 7   NVDA         Neutral         0.999958
# 8   NVDA         Neutral         0.787294
# 9    AMD        Negative         0.907116
#
#                                                title
# 0  Apple Stock (AAPL) Before the US Market Open (...
# 1  Apple Stock Gets Three Price-Target Hikes. Her...
# 2  Apple Inc. Stock (AAPL) Opinions on AI Develop...
# 3  MSFT vs. GOOGL vs. NVDA: Which ‘Strong Buy’ Me...
# 4  Microsoft Stock (MSFT) After Hours on Dec. 12,...
# 5  Better (Almost) $4 Trillion AI Stock to Buy No...
# 6  Could Nvidia Be the Most Undervalued Stock in ...
# 7  The Saturday Spread: Here’s How to Properly Tr...
# 8  Nvidia Stock (NVDA) Before the Market Opens De...
# 9  Why AMD (AMD) Shares Are Sliding Today - Yahoo...

# %%
def collect_all_data_for_ticker(ticker):
    """
    Master function: Collect ALL data for a single ticker
    Returns: dict with OHLCV, fundamentals, insider, sentiment
    """
    print(f"📊 {ticker}...", end=' ')
    
    data = {'ticker': ticker}
    
    try:
        # 1. OHLCV from yfinance
        ohlcv = yf.download(ticker, period='2y', progress=False)
        if not ohlcv.empty:
            data['bars_count'] = len(ohlcv)
            data['last_price'] = float(ohlcv['Close'].iloc[-1])
            data['avg_volume'] = float(ohlcv['Volume'].mean())
            data['volatility'] = float(ohlcv['Close'].pct_change().std() * np.sqrt(252))
            # Momentum
            data['return_1m'] = float((ohlcv['Close'].iloc[-1] / ohlcv['Close'].iloc[-20] - 1) * 100)
            data['return_3m'] = float((ohlcv['Close'].iloc[-1] / ohlcv['Close'].iloc[-60] - 1) * 100)
        
        time.sleep(0.3)
        
        # 2. Fundamentals from multi-source collector
        fundamentals = collect_fundamentals_multisource(ticker)
        # Extract just the values, not the source attribution
        for field, field_data in fundamentals.items():
            if field != 'ticker' and isinstance(field_data, dict):
                data[field] = field_data.get('value')
        time.sleep(1)
        
        # 3. Insider trades from SEC
        insider = get_sec_insider_trades(ticker)
        data['insider_trades_count'] = insider.get('insider_trades', 0)
        time.sleep(2)
        
        # 4. News sentiment
        news = scrape_google_news(ticker, max_articles=5)
        if news and len(news) > 0:
            analyzed = analyze_sentiment_batch(news, batch_size=5)
            if analyzed:
                sentiments = [n.get('sentiment_numeric', 0) for n in analyzed if 'sentiment_numeric' in n]
                data['news_count'] = len(analyzed)
                data['avg_sentiment'] = np.mean(sentiments) if sentiments else 0
                data['sentiment_std'] = np.std(sentiments) if len(sentiments) > 1 else 0
        time.sleep(0.5)
        
        print("✓")
        
    except Exception as e:
        print(f"✗ ({str(e)[:30]})")
        data['error'] = str(e)
    
    return data

# TEST on 10 tickers
print("\\n🔬 FULL DATA COLLECTION TEST (10 tickers)\\n")
test_batch = TICKERS[:10]
all_ticker_data = []

for ticker in test_batch:
    ticker_data = collect_all_data_for_ticker(ticker)
    all_ticker_data.append(ticker_data)

# Convert to dataframe
results_df = pd.DataFrame(all_ticker_data)
print(f"\\n✅ Collected data for {len(results_df)} tickers")
print(f"\\nColumns collected: {list(results_df.columns)}")
print("\\nSample results (all available columns):")
# Show only columns that exist
available_cols = ['ticker', 'last_price', 'return_1m']
available_cols.extend([c for c in ['avg_sentiment', 'insider_trades_count', 'market_cap', 'trailing_pe'] if c in results_df.columns])
print(results_df[available_cols].head())
# Out:
# \n🔬 FULL DATA COLLECTION TEST (10 tickers)\n
# 📊 AAPL...
# 2025-12-14 23:01:11,800 - INFO - === Starting collection for AAPL ===
# 2025-12-14 23:01:12,074 - INFO - [AAPL] Retrieved 9 fields from yfinance
# 2025-12-14 23:01:12,074 - INFO - [AAPL] Trying fmp fallback...
# 2025-12-14 23:01:12,296 - WARNING - [AAPL] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/AAPL?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:01:12,298 - INFO - [AAPL] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:01:12,583 - INFO - [AAPL] Found PEG ratio from alpha_vantage
# 2025-12-14 23:01:27,585 - INFO - === Completed AAPL. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.12s (41.8 texts/sec)
# ✓
# 📊 MSFT...
# 2025-12-14 23:01:32,893 - INFO - === Starting collection for MSFT ===
# 2025-12-14 23:01:33,095 - INFO - [MSFT] Retrieved 9 fields from yfinance
# 2025-12-14 23:01:33,096 - INFO - [MSFT] Trying fmp fallback...
# 2025-12-14 23:01:33,311 - WARNING - [MSFT] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/MSFT?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:01:33,313 - INFO - [MSFT] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:01:33,545 - INFO - [MSFT] Found PEG ratio from alpha_vantage
# 2025-12-14 23:01:48,547 - INFO - === Completed MSFT. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.14s (36.9 texts/sec)
# ✓
# 📊 NVDA...
# 2025-12-14 23:01:53,762 - INFO - === Starting collection for NVDA ===
# 2025-12-14 23:01:53,990 - INFO - [NVDA] Retrieved 9 fields from yfinance
# 2025-12-14 23:01:53,992 - INFO - [NVDA] Trying fmp fallback...
# 2025-12-14 23:01:54,276 - WARNING - [NVDA] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/NVDA?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:01:54,278 - INFO - [NVDA] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:01:54,525 - INFO - [NVDA] Found PEG ratio from alpha_vantage
# 2025-12-14 23:02:09,527 - INFO - === Completed NVDA. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.12s (42.2 texts/sec)
# ✓
# 📊 AMD...
# 2025-12-14 23:02:14,819 - INFO - === Starting collection for AMD ===
# 2025-12-14 23:02:15,035 - INFO - [AMD] Retrieved 9 fields from yfinance
# 2025-12-14 23:02:15,036 - INFO - [AMD] Trying fmp fallback...
# 2025-12-14 23:02:15,336 - WARNING - [AMD] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/AMD?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:02:15,338 - INFO - [AMD] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:02:15,565 - INFO - [AMD] Found PEG ratio from alpha_vantage
# 2025-12-14 23:02:30,567 - INFO - === Completed AMD. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.20s (24.7 texts/sec)
# ✓
# 📊 AVGO...
# 2025-12-14 23:02:36,087 - INFO - === Starting collection for AVGO ===
# 2025-12-14 23:02:36,307 - INFO - [AVGO] Retrieved 9 fields from yfinance
# 2025-12-14 23:02:36,308 - INFO - [AVGO] Trying fmp fallback...
# 2025-12-14 23:02:36,523 - WARNING - [AVGO] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/AVGO?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:02:36,524 - INFO - [AVGO] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:02:36,768 - INFO - [AVGO] Found PEG ratio from alpha_vantage
# 2025-12-14 23:02:51,771 - INFO - === Completed AVGO. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.13s (38.8 texts/sec)
# ✓
# 📊 MSTR...
# 2025-12-14 23:02:57,191 - INFO - === Starting collection for MSTR ===
# 2025-12-14 23:02:57,426 - INFO - [MSTR] Retrieved 9 fields from yfinance
# 2025-12-14 23:02:57,427 - INFO - [MSTR] Trying fmp fallback...
# 2025-12-14 23:02:57,661 - WARNING - [MSTR] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/MSTR?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:02:57,663 - INFO - [MSTR] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:02:57,908 - INFO - [MSTR] Found PEG ratio from alpha_vantage
# 2025-12-14 23:03:12,910 - INFO - === Completed MSTR. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.14s (35.2 texts/sec)
# ✓
# 📊 IONQ...
# 2025-12-14 23:03:18,217 - INFO - === Starting collection for IONQ ===
# 2025-12-14 23:03:18,514 - INFO - [IONQ] Retrieved 8 fields from yfinance
# 2025-12-14 23:03:18,515 - INFO - [IONQ] Trying fmp fallback...
# 2025-12-14 23:03:18,750 - WARNING - [IONQ] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/IONQ?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:03:18,751 - INFO - [IONQ] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:03:33,984 - INFO - === Completed IONQ. Fields found: 8/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.12s (40.2 texts/sec)
# ✓
# 📊 GOOGL...
# 2025-12-14 23:03:39,295 - INFO - === Starting collection for GOOGL ===
# 2025-12-14 23:03:39,556 - INFO - [GOOGL] Retrieved 9 fields from yfinance
# 2025-12-14 23:03:39,557 - INFO - [GOOGL] Trying fmp fallback...
# 2025-12-14 23:03:39,771 - WARNING - [GOOGL] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/GOOGL?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:03:39,773 - INFO - [GOOGL] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:03:40,059 - INFO - [GOOGL] Found PEG ratio from alpha_vantage
# 2025-12-14 23:03:55,062 - INFO - === Completed GOOGL. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.14s (36.9 texts/sec)
# ✓
# 📊 META...
# 2025-12-14 23:04:00,468 - INFO - === Starting collection for META ===
# 2025-12-14 23:04:00,682 - INFO - [META] Retrieved 9 fields from yfinance
# 2025-12-14 23:04:00,683 - INFO - [META] Trying fmp fallback...
# 2025-12-14 23:04:00,901 - WARNING - [META] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/META?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:04:00,902 - INFO - [META] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:04:01,143 - INFO - [META] Found PEG ratio from alpha_vantage
# 2025-12-14 23:04:16,145 - INFO - === Completed META. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.17s (30.2 texts/sec)
# ✓
# 📊 TSLA...
# 2025-12-14 23:04:21,451 - INFO - === Starting collection for TSLA ===
# 2025-12-14 23:04:21,683 - INFO - [TSLA] Retrieved 9 fields from yfinance
# 2025-12-14 23:04:21,683 - INFO - [TSLA] Trying fmp fallback...
# 2025-12-14 23:04:21,905 - WARNING - [TSLA] Network error from fmp: 403 Client Error: Forbidden for url: https://financialmodelingprep.com/api/v3/profile/TSLA?apikey=15zYYtksuJnQsTBODSNs3MrfEedOSd3i
# 2025-12-14 23:04:21,907 - INFO - [TSLA] Trying alpha_vantage for PEG ratio...
# 2025-12-14 23:04:22,150 - INFO - [TSLA] Found PEG ratio from alpha_vantage
# 2025-12-14 23:04:37,152 - INFO - === Completed TSLA. Fields found: 10/10 ===
# 🔄 Analyzing 5 headlines on GPU...
# ✅ Processed 5 texts in 0.12s (40.6 texts/sec)
# ✓
# \n✅ Collected data for 10 tickers
# \nColumns collected: ['ticker', 'bars_count', 'last_price', 'avg_volume', 'volatility', 'return_1m', 'return_3m', 'market_cap', 'trailing_pe', 'forward_pe', 'peg_ratio', 'short_pct', 'insider_pct', 'institution_pct', 'beta', 'price_to_book', 'price_to_sales', 'insider_trades_count', 'news_count', 'avg_sentiment', 'sentiment_std']
# \nSample results (all available columns):
#   ticker  last_price  return_1m  avg_sentiment  insider_trades_count  \
# 0   AAPL  278.279999   2.154838       0.000000                     8
# 1   MSFT  478.529999  -6.028138       0.399564                    10
# 2   NVDA  175.020004  -7.961428       0.207773                    10
# 3    AMD  210.779999 -14.598274      -0.256164                     8
# 4   AVGO  359.929993   5.101326       0.000000                     8
#
#       market_cap  trailing_pe
# 0  4129783545856    37.302948
# 1  3556993138688    34.010662
# 2  4261212061696    43.321785
# 3   343158620160   109.781250
# 4  1699720724480    75.141960

# %%
def calculate_composite_score(df):
    """
    Calculate multi-factor score for ranking stocks
    
    Factors:
    1. Momentum (30%): 1-month and 3-month returns
    2. Sentiment (20%): News sentiment score
    3. Insider Activity (15%): Recent Form 4 filings
    4. Volatility (15%): Higher vol = more opportunity
    5. Value (10%): P/E ratio (lower better)
    6. Short Interest (10%): High short % = squeeze potential
    """
    
    scores = pd.DataFrame(index=df.index)
    
    # 1. Momentum Score (30%)
    df['return_1m_clean'] = pd.to_numeric(df['return_1m'], errors='coerce')
    df['return_3m_clean'] = pd.to_numeric(df['return_3m'], errors='coerce')
    
    scores['momentum'] = (
        df['return_1m_clean'].fillna(0) * 0.6 + 
        df['return_3m_clean'].fillna(0) * 0.4
    )
    
    # 2. Sentiment Score (20%)
    scores['sentiment'] = df['avg_sentiment'].fillna(0) * 100
    
    # 3. Insider Activity Score (15%)
    scores['insider'] = df['insider_trades_count'].fillna(0) * 10
    
    # 4. Volatility Score (15%) - normalized
    df['volatility_clean'] = pd.to_numeric(df['volatility'], errors='coerce')
    scores['volatility'] = df['volatility_clean'].fillna(0) * 100
    
    # 5. Value Score (10%) - inverse P/E
    df['pe_clean'] = df['trailing_pe'].replace('N/A', np.nan)
    df['pe_clean'] = pd.to_numeric(df['pe_clean'], errors='coerce')
    scores['value'] = 100 / (df['pe_clean'].fillna(50) + 1)  # Lower P/E = higher score
    
    # 6. Short Interest Score (10%)
    df['short_clean'] = df['short_pct'].replace('N/A', np.nan)
    df['short_clean'] = pd.to_numeric(df['short_clean'].str.rstrip('%'), errors='coerce')
    scores['short_squeeze'] = df['short_clean'].fillna(0) * 2
    
    # Normalize all scores to 0-100
    for col in scores.columns:
        min_val = scores[col].min()
        max_val = scores[col].max()
        if max_val > min_val:
            scores[col] = (scores[col] - min_val) / (max_val - min_val) * 100
    
    # Composite score with weights
    weights = {
        'momentum': 0.30,
        'sentiment': 0.20,
        'insider': 0.15,
        'volatility': 0.15,
        'value': 0.10,
        'short_squeeze': 0.10
    }
    
    df['composite_score'] = sum(scores[factor] * weight for factor, weight in weights.items())
    
    # Add individual factor scores
    for factor in scores.columns:
        df[f'{factor}_score'] = scores[factor]
    
    return df

# Apply scoring to test data
if len(results_df) > 0:
    print("🎯 Calculating composite scores...")
    scored_df = calculate_composite_score(results_df.copy())
    
    # Rank by score
    scored_df = scored_df.sort_values('composite_score', ascending=False)
    
    print("\n🏆 TOP RANKED TICKERS:")
    print(scored_df[['ticker', 'composite_score', 'momentum_score', 
                     'sentiment_score', 'insider_score', 'last_price']].head(10))
# Out:
# 🎯 Calculating composite scores...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 73
#      71 if len(results_df) > 0:
#      72     print("🎯 Calculating composite scores...")
# ---> 73     scored_df = calculate_composite_score(results_df.copy())
#      75     # Rank by score
#      76     scored_df = scored_df.sort_values('composite_score', ascending=False)
#
# Cell In[38], line 42, in calculate_composite_score(df)
#      40 # 6. Short Interest Score (10%)
#      41 df['short_clean'] = df['short_pct'].replace('N/A', np.nan)
# ---> 42 df['short_clean'] = pd.to_numeric(df['short_clean'].str.rstrip('%'), errors='coerce')
#      43 scores['short_squeeze'] = df['short_clean'].fillna(0) * 2
#      45 # Normalize all scores to 0-100
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
# WARNING: This will take 2-3 hours for 353 tickers
# Uncomment to run full pipeline

# print("=" * 60)
# print("🚀 RUNNING FULL PIPELINE ON 353 TICKERS")
# print("=" * 60)
# print(f"Started: {datetime.now()}")
# print(f"Estimated time: 2-3 hours\\n")

# all_results = []
# failed_tickers = []

# for i, ticker in enumerate(TICKERS, 1):
#     print(f"[{i}/{len(TICKERS)}] ", end='')
#     try:
#         data = collect_all_data_for_ticker(ticker)
#         all_results.append(data)
#     except Exception as e:
#         print(f"{ticker} FAILED: {e}")
#         failed_tickers.append(ticker)
    
#     # Save checkpoint every 50 tickers
#     if i % 50 == 0:
#         checkpoint_df = pd.DataFrame(all_results)
#         checkpoint_df.to_csv(f'{DATA_DIR}/checkpoint_{i}.csv', index=False)
#         print(f"\\n📁 Checkpoint saved: {i} tickers\\n")

# # Final save
# final_df = pd.DataFrame(all_results)
# final_df.to_csv(f'{DATA_DIR}/all_353_tickers_raw.csv', index=False)

# print(f"\\n✅ COMPLETE at {datetime.now()}")
# print(f"Success: {len(all_results)}, Failed: {len(failed_tickers)}")

print("⚠️ FULL PIPELINE READY - Uncomment above code to run")
print("💡 Recommended: Start with 30-50 tickers first to validate")

# %%
# WARNING: This will take 2-3 hours for 353 tickers
# Uncomment to run full pipeline

# print("=" * 60)
# print("🚀 RUNNING FULL PIPELINE ON 353 TICKERS")
# print("=" * 60)
# print(f"Started: {datetime.now()}")
# print(f"Estimated time: 2-3 hours\\n")

# all_results = []
# failed_tickers = []

# for i, ticker in enumerate(TICKERS, 1):
#     print(f"[{i}/{len(TICKERS)}] ", end='')
#     try:
#         data = collect_all_data_for_ticker(ticker)
#         all_results.append(data)
#     except Exception as e:
#         print(f"{ticker} FAILED: {e}")
#         failed_tickers.append(ticker)
    
#     # Save checkpoint every 50 tickers
#     if i % 50 == 0:
#         checkpoint_df = pd.DataFrame(all_results)
#         checkpoint_df.to_csv(f'{DATA_DIR}/checkpoint_{i}.csv', index=False)
#         print(f"\\n📁 Checkpoint saved: {i} tickers\\n")

# # Final save
# final_df = pd.DataFrame(all_results)
# final_df.to_csv(f'{DATA_DIR}/all_353_tickers_raw.csv', index=False)

# print(f"\\n✅ COMPLETE at {datetime.now()}")
# print(f"Success: {len(all_results)}, Failed: {len(failed_tickers)}")

print("⚠️ FULL PIPELINE READY - Uncomment above code to run")
print("💡 Recommended: Start with 30-50 tickers first to validate")

# %%
# After running full pipeline, use this to extract top 50

# # Load raw data
# full_df = pd.read_csv(f'{DATA_DIR}/all_353_tickers_raw.csv')

# # Calculate scores
# scored_df = calculate_composite_score(full_df)

# # Rank and select top 50
# top50 = scored_df.nlargest(50, 'composite_score')

# # Save results
# top50.to_csv(OUTPUT_FILE, index=False)

# print("🏆 TOP 50 TICKERS SELECTED")
# print("\nBreakdown by sector:")
# print(top50['sector'].value_counts())
# print("\nTop 10:")
# print(top50[['ticker', 'composite_score', 'sector', 'last_price', 
#              'return_1m', 'avg_sentiment']].head(10))

# # Create watchlist file
# with open(f'{DATA_DIR}/top50_watchlist.txt', 'w') as f:
#     for ticker in top50['ticker']:
#         f.write(f"{ticker}\\n")

# print(f"\n✅ Saved to: {OUTPUT_FILE}")
# print(f"✅ Watchlist: {DATA_DIR}/top50_watchlist.txt")

print("⚠️ Run after full pipeline completes")

# %%
# Import everything we need
import sys
sys.path.append('/workspaces/quantum-ai-trader_v1.1')

import yfinance as yf
import pandas as pd
import numpy as np
import time
import json
from datetime import datetime, timedelta
from pathlib import Path
from IPython.display import display, HTML, clear_output

from day1_foundation_database import TradingDatabase

print("✅ All imports loaded")
print(f"🕐 Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 14
#      11 from pathlib import Path
#      12 from IPython.display import display, HTML, clear_output
# ---> 14 from day1_foundation_database import TradingDatabase
#      16 print("✅ All imports loaded")
#      17 print(f"🕐 Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
#
# ModuleNotFoundError: No module named 'day1_foundation_database'

# %%
# Import everything we need
import sys
sys.path.append('/workspaces/quantum-ai-trader_v1.1')

import yfinance as yf
import pandas as pd
import numpy as np
import time
import json
from datetime import datetime, timedelta
from pathlib import Path
from IPython.display import display, HTML, clear_output

from day1_foundation_database import TradingDatabase

print("✅ All imports loaded")
print(f"🕐 Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 14
#      11 from pathlib import Path
#      12 from IPython.display import display, HTML, clear_output
# ---> 14 from day1_foundation_database import TradingDatabase
#      16 print("✅ All imports loaded")
#      17 print(f"🕐 Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
#
# ModuleNotFoundError: No module named 'day1_foundation_database'

# %%
# Import everything we need
import sys
sys.path.append('/workspaces/quantum-ai-trader_v1.1')

import yfinance as yf
import pandas as pd
import numpy as np
import time
import json
from datetime import datetime, timedelta
from pathlib import Path
from IPython.display import display, HTML, clear_output

from day1_foundation_database import TradingDatabase

print("✅ All imports loaded")
print(f"🕐 Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 14
#      11 from pathlib import Path
#      12 from IPython.display import display, HTML, clear_output
# ---> 14 from day1_foundation_database import TradingDatabase
#      16 print("✅ All imports loaded")
#      17 print(f"🕐 Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
#
# ModuleNotFoundError: No module named 'day1_foundation_database'

# %%
# SELF-CONTAINED - Works on Codespace AND Shadow PC
# No external imports - everything embedded

import yfinance as yf
import pandas as pd
import numpy as np
import time
import json
import sqlite3
import os
from datetime import datetime, timedelta
from pathlib import Path
from IPython.display import display, HTML, clear_output

# Auto-detect environment (Codespace vs Shadow PC)
if os.path.exists('/workspaces/quantum-ai-trader_v1.1'):
    WORKSPACE = '/workspaces/quantum-ai-trader_v1.1'
    ENV = 'Codespace'
elif os.path.exists(r'C:\Users\Shadow\quantum-ai-trader_v1.1'):
    WORKSPACE = r'C:\Users\Shadow\quantum-ai-trader_v1.1'
    ENV = 'Shadow PC'
else:
    # Fallback to notebook's parent directory
    WORKSPACE = str(Path.cwd().parent)
    ENV = 'Unknown'

DATA_DIR = os.path.join(WORKSPACE, 'data')
DB_PATH = os.path.join(DATA_DIR, 'trading_system.db')
CHECKPOINT_FILE = os.path.join(DATA_DIR, 'ohlcv_checkpoint.json')

# Ensure directories exist
os.makedirs(DATA_DIR, exist_ok=True)

print(f"✅ Environment: {ENV}")
print(f"📁 Workspace: {WORKSPACE}")
print(f"💾 Database: {DB_PATH}")
print(f"🕐 Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✅ Environment: Shadow PC
# 📁 Workspace: C:\Users\Shadow\quantum-ai-trader_v1.1
# 💾 Database: C:\Users\Shadow\quantum-ai-trader_v1.1\data\trading_system.db
# 🕐 Started: 2025-12-14 23:33:56

# %%
# DATABASE CLASS - EMBEDDED (no external imports needed)

class TradingDatabase:
    """Production database - embedded in notebook for portability."""
    
    def __init__(self, db_path=DB_PATH):
        self.db_path = db_path
        self.conn = None
        
    def connect(self):
        """Connect to database with optimizations."""
        self.conn = sqlite3.connect(self.db_path, timeout=30.0)
        self.conn.execute("PRAGMA journal_mode=WAL")
        self.conn.execute("PRAGMA synchronous=NORMAL")
        self.conn.execute("PRAGMA cache_size=-64000")
        return self.conn
    
    def close(self):
        if self.conn:
            self.conn.close()
            self.conn = None
    
    def create_schema(self):
        """Create database tables."""
        cursor = self.conn.cursor()
        
        # Tickers table
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS tickers (
                ticker TEXT PRIMARY KEY,
                sector TEXT,
                industry TEXT,
                market_cap_category TEXT,
                notes TEXT,
                active BOOLEAN DEFAULT 1,
                added_date TEXT DEFAULT CURRENT_TIMESTAMP
            )
        """)
        
        # OHLCV table
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS ohlcv_daily (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                ticker TEXT NOT NULL,
                date TEXT NOT NULL,
                open REAL, high REAL, low REAL, close REAL,
                volume INTEGER, adj_close REAL,
                created_at TEXT DEFAULT CURRENT_TIMESTAMP,
                UNIQUE(ticker, date)
            )
        """)
        cursor.execute("CREATE INDEX IF NOT EXISTS idx_ohlcv_ticker_date ON ohlcv_daily(ticker, date)")
        
        self.conn.commit()
    
    def load_ticker_universe(self, csv_path):
        """Load tickers from CSV."""
        if not os.path.exists(csv_path):
            print(f"⚠️ CSV not found, creating from active tickers...")
            return 0
        df = pd.read_csv(csv_path)
        df.to_sql('tickers', self.conn, if_exists='replace', index=False)
        self.conn.commit()
        return len(df)
    
    def get_active_tickers(self):
        """Get all active tickers."""
        query = "SELECT ticker FROM tickers WHERE active = 1 ORDER BY ticker"
        return pd.read_sql_query(query, self.conn)['ticker'].tolist()
    
    def insert_ohlcv_batch(self, ticker, ohlcv_df):
        """Insert OHLCV data."""
        if ohlcv_df.empty:
            return 0
        
        ohlcv_df = ohlcv_df.reset_index()
        ohlcv_df['ticker'] = ticker
        ohlcv_df['date'] = pd.to_datetime(ohlcv_df['Date']).dt.strftime('%Y-%m-%d')
        ohlcv_df['created_at'] = datetime.now().isoformat()
        
        col_mapping = {
            'Open': 'open', 'High': 'high', 'Low': 'low',
            'Close': 'close', 'Volume': 'volume', 'Adj Close': 'adj_close'
        }
        ohlcv_df = ohlcv_df.rename(columns=col_mapping)
        
        cols = ['ticker', 'date', 'open', 'high', 'low', 'close', 'volume', 'adj_close', 'created_at']
        insert_df = ohlcv_df[cols]
        
        insert_df.to_sql('ohlcv_daily', self.conn, if_exists='append', index=False)
        self.conn.commit()
        return len(insert_df)
    
    def get_latest_ohlcv_date(self, ticker):
        """Get most recent date for ticker."""
        query = "SELECT MAX(date) as max_date FROM ohlcv_daily WHERE ticker = ?"
        result = pd.read_sql_query(query, self.conn, params=[ticker])
        return result['max_date'].iloc[0] if not result.empty else None
    
    def get_database_stats(self):
        """Get database statistics."""
        cursor = self.conn.cursor()
        stats = {}
        
        cursor.execute("SELECT COUNT(*) FROM tickers WHERE active = 1")
        stats['active_tickers'] = cursor.fetchone()[0]
        
        cursor.execute("""
            SELECT COUNT(DISTINCT ticker) as tickers_with_data,
                   MIN(date) as earliest_date,
                   MAX(date) as latest_date,
                   COUNT(*) as total_bars
            FROM ohlcv_daily
        """)
        row = cursor.fetchone()
        stats['ohlcv_tickers'] = row[0]
        stats['ohlcv_earliest'] = row[1]
        stats['ohlcv_latest'] = row[2]
        stats['ohlcv_total_bars'] = row[3]
        
        return stats

# Initialize database
db = TradingDatabase()
db.connect()
db.create_schema()

# Load ticker universe
UNIVERSE_FILE = os.path.join(DATA_DIR, 'ticker_universe_300.csv')
ticker_count = db.load_ticker_universe(UNIVERSE_FILE)

# Get all tickers
all_tickers = db.get_active_tickers()
print(f"\n📊 Total universe: {len(all_tickers)} tickers")
print(f"Sample: {all_tickers[:20]}")

# Check current database state
stats = db.get_database_stats()
print(f"\n📁 Current database state:")
print(f"   Tickers with data: {stats['ohlcv_tickers']}")
print(f"   Total bars: {stats['ohlcv_total_bars']:,}")

if stats['ohlcv_tickers'] > 0:
    print(f"   Date range: {stats['ohlcv_earliest']} to {stats['ohlcv_latest']}")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such column: active
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[2], line 133
#     130 ticker_count = db.load_ticker_universe(UNIVERSE_FILE)
#     132 # Get all tickers
# --> 133 all_tickers = db.get_active_tickers()
#     134 print(f"\n📊 Total universe: {len(all_tickers)} tickers")
#     135 print(f"Sample: {all_tickers[:20]}")
#
# Cell In[2], line 69, in TradingDatabase.get_active_tickers(self)
#      67 """Get all active tickers."""
#      68 query = "SELECT ticker FROM tickers WHERE active = 1 ORDER BY ticker"
# ---> 69 return pd.read_sql_query(query, self.conn)['ticker'].tolist()
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\io\sql.py:528, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     525 assert dtype_backend is not lib.no_default
#     527 with pandasSQL_builder(con) as pandas_sql:
# --> 528     return pandas_sql.read_query(
#     529         sql,
#     530         index_col=index_col,
#     531         params=params,
#     532         coerce_float=coerce_float,
#     533         parse_dates=parse_dates,
#     534         chunksize=chunksize,
#     535         dtype=dtype,
#     536         dtype_backend=dtype_backend,
#     537     )
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\io\sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~\Desktop\shadow_ai\Lib\site-packages\pandas\io\sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT ticker FROM tickers WHERE active = 1 ORDER BY ticker': no such column: active
